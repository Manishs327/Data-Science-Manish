# %% [markdown]
# ### 1. Let us start by importing all the necessary libraries which will be required in our analysis

# %%
#Importing libraries
import nltk, re, pprint
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import pprint, time
import random
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

# %%
nltk.download('treebank')
nltk.download('punkt')
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %% [markdown]
# ### 2. Now

# %%
# reading the Treebank tagged sentences
wsj = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
# Splitting into train and validation
random.seed(1234)
train_set, validation_set = train_test_split(wsj,test_size=0.05)

print(len(train_set))
print(len(validation_set))
# Out:
# 3718
# 196

# %%
train_set_words = [i for j in train_set for i in j]

# %%
len(train_set_words)
# Out:
# 95617

# %%
unique_words_set = set(train_set_words)

# %%
len(unique_words_set)
# Out:
# 12810

# %%
tokens_in_train = [i[0] for i in train_set_words]

# %%
unique_tokens_train = set(tokens_in_train)

# %%
len(tokens_in_train)
# Out:
# 95617

# %%
len(unique_tokens_train)
# Out:
# 12081

# %%
tags_train = [i[1] for i in train_set_words]

# %%
len(tags_train)
# Out:
# 95617

# %%
unique_tags_train = set(tags_train)

# %%
len(unique_tags_train)
# Out:
# 12

# %%
print(unique_tags_train)
# Out:
# {'NOUN', 'NUM', 'CONJ', '.', 'PRON', 'DET', 'PRT', 'ADP', 'ADV', 'X', 'VERB', 'ADJ'}

# %% [markdown]
# ### Emission Probabilities

# %%
# compute word given tag: Emission Probability
# compute word given tag: Emission Probability
def word_given_tag(word, tag, train_bag = train_set_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %%
# examples

# large
print("\n", "large")
print(word_given_tag('large', 'ADJ'))
print(word_given_tag('large', 'VERB'))
print(word_given_tag('large', 'NOUN'), "\n")

# will
print("\n", "will")
print(word_given_tag('will', 'VERB'))
print(word_given_tag('will', 'NOUN'))

# book
print("\n", "book")
print(word_given_tag('book', 'NOUN'))
print(word_given_tag('book', 'VERB'))

# He
print("\n", "He")
print(word_given_tag('He', 'NOUN'))
print(word_given_tag('He', 'PRON'))

# one
print("\n", "one")
print(word_given_tag('one', 'NOUN'))
print(word_given_tag('one', 'NUM'))
print(word_given_tag('one', 'ADP'))
# Out:
#  large
# (29, 6064)
# (0, 12849)
# (0, 27490)
#
#
#  will
# (259, 12849)
# (1, 27490)
#
#  book
# (7, 27490)
# (0, 12849)
#
#  He
# (0, 27490)
# (69, 2587)
#
#  one
# (9, 27490)
# (116, 3386)
# (0, 9350)

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability

def t2_given_t1(t2, t1, train_bag = train_set_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# examples
print(t2_given_t1(t2='NOUN', t1='ADJ'))
print(t2_given_t1('NOUN', 'DET'))
print(t2_given_t1('NOUN', 'VERB'))
print(t2_given_t1('.', 'NOUN'))
print(t2_given_t1('VERB', 'NOUN'))
# Out:
# (4244, 6064)
# (5275, 8244)
# (1409, 12849)
# (6595, 27490)
# (4038, 27490)

# %%
#Please note P(tag|start) is same as P(tag|'.')
print(t2_given_t1('DET', '.'))
print(t2_given_t1('VERB', '.'))
print(t2_given_t1('NOUN', '.'))
# Out:
# (1920, 11148)
# (991, 11148)
# (2491, 11148)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len(unique_tags_train), len(unique_tags_train)), dtype='float32')
for i, t1 in enumerate(list(unique_tags_train)):
    for j, t2 in enumerate(list(unique_tags_train)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

tags_matrix
# Out:
# array([[2.65223712e-01, 9.63986944e-03, 4.25609313e-02, 2.39905417e-01,
#         4.87449998e-03, 1.30229173e-02, 4.39432524e-02, 1.75773010e-01,
#         1.71335023e-02, 2.91014910e-02, 1.46889776e-01, 1.19316112e-02],
#        [3.52923810e-01, 1.84288248e-01, 1.35853514e-02, 1.16952159e-01,
#         1.47666864e-03, 3.83933843e-03, 2.74660364e-02, 3.51447128e-02,
#         2.95333727e-03, 2.10868284e-01, 1.83106903e-02, 3.21913771e-02],
#        [3.49397600e-01, 4.21686731e-02, 4.63392033e-04, 3.47544029e-02,
#         5.74606098e-02, 1.19091749e-01, 4.63392027e-03, 5.28266914e-02,
#         5.51436506e-02, 7.41427252e-03, 1.58016682e-01, 1.18628360e-01],
#        [2.23448157e-01, 8.11804831e-02, 5.81270196e-02, 9.25726593e-02,
#         6.51237890e-02, 1.72228202e-01, 2.42195907e-03, 9.10477191e-02,
#         5.29242903e-02, 2.75385715e-02, 8.88948664e-02, 4.44025844e-02],
#        [2.10668728e-01, 7.73096271e-03, 5.02512557e-03, 3.98144573e-02,
#         7.34441448e-03, 9.27715469e-03, 1.31426360e-02, 2.35794354e-02,
#         3.40162367e-02, 9.35446471e-02, 4.80479330e-01, 7.53768831e-02],
#        [6.39859319e-01, 2.23192628e-02, 4.85201366e-04, 1.73459481e-02,
#         3.51770991e-03, 5.57981571e-03, 2.42600683e-04, 8.97622481e-03,
#         1.26152355e-02, 4.52450253e-02, 3.94226089e-02, 2.04391077e-01],
#        [2.47877210e-01, 5.68256043e-02, 2.28608749e-03, 4.37622480e-02,
#         1.89418681e-02, 1.01241022e-01, 1.63291965e-03, 2.05747876e-02,
#         1.01241022e-02, 1.37165254e-02, 3.98758978e-01, 8.42586532e-02],
#        [3.24705869e-01, 6.29946515e-02, 8.55614955e-04, 3.96791436e-02,
#         6.83422461e-02, 3.23208570e-01, 1.49732619e-03, 1.70053467e-02,
#         1.34759359e-02, 3.43315490e-02, 8.66310205e-03, 1.05240643e-01],
#        [3.22795324e-02, 3.26123126e-02, 6.98835263e-03, 1.37437597e-01,
#         1.56405997e-02, 6.85524121e-02, 1.49750412e-02, 1.17470883e-01,
#         7.85357729e-02, 2.26289518e-02, 3.43760401e-01, 1.29118130e-01],
#        [6.27988502e-02, 2.86898320e-03, 1.05196051e-02, 1.64010197e-01,
#         5.45106791e-02, 5.41919023e-02, 1.82977363e-01, 1.45521194e-01,
#         2.64583994e-02, 7.42747858e-02, 2.04335347e-01, 1.75326746e-02],
#        [1.09658338e-01, 2.30368115e-02, 5.44789480e-03, 3.57226245e-02,
#         3.58782783e-02, 1.33784726e-01, 3.17534432e-02, 9.19137672e-02,
#         8.05510134e-02, 2.18149275e-01, 1.68106467e-01, 6.59973547e-02],
#        [6.99868083e-01, 2.01187339e-02, 1.71503965e-02, 6.56332448e-02,
#         4.94722975e-04, 4.61741444e-03, 1.12137208e-02, 7.68469647e-02,
#         4.78232186e-03, 2.01187339e-02, 1.18733505e-02, 6.72823191e-02]],
#       dtype=float32)

# %%
# convert the matrix to a df for better readability
tags_df = pd.DataFrame(tags_matrix, columns = list(unique_tags_train), index=list(unique_tags_train))
tags_df
# Out:
#           NOUN       NUM      CONJ  ...         X      VERB       ADJ
# NOUN  0.265224  0.009640  0.042561  ...  0.029101  0.146890  0.011932
# NUM   0.352924  0.184288  0.013585  ...  0.210868  0.018311  0.032191
# CONJ  0.349398  0.042169  0.000463  ...  0.007414  0.158017  0.118628
# .     0.223448  0.081180  0.058127  ...  0.027539  0.088895  0.044403
# PRON  0.210669  0.007731  0.005025  ...  0.093545  0.480479  0.075377
# DET   0.639859  0.022319  0.000485  ...  0.045245  0.039423  0.204391
# PRT   0.247877  0.056826  0.002286  ...  0.013717  0.398759  0.084259
# ADP   0.324706  0.062995  0.000856  ...  0.034332  0.008663  0.105241
# ADV   0.032280  0.032612  0.006988  ...  0.022629  0.343760  0.129118
# X     0.062799  0.002869  0.010520  ...  0.074275  0.204335  0.017533
# VERB  0.109658  0.023037  0.005448  ...  0.218149  0.168106  0.065997
# ADJ   0.699868  0.020119  0.017150  ...  0.020119  0.011873  0.067282
#
# [12 rows x 12 columns]

# %%
tags_df.loc['.', :]
# Out:
# NOUN    0.223448
# NUM     0.081180
# CONJ    0.058127
# .       0.092573
# PRON    0.065124
# DET     0.172228
# PRT     0.002422
# ADP     0.091048
# ADV     0.052924
# X       0.027539
# VERB    0.088895
# ADJ     0.044403
# Name: ., dtype: float32

# %%
len(train_set_words)
# Out:
# 95617

# %%
# Viterbi Heuristic
def Viterbi(words, train_bag = train_set_words):
    state=[]
    map_word_state = {}
    T = list(set([pair[1] for pair in train_bag]))
    V = list(set([pair[0] for pair in train_bag]))
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)]
        map_word_state[word] = state_max
        state.append(state_max)
        
    return list(zip(words,state))

# %%
# list of tagged words
validation_run_base = [tup for sent in validation_set for tup in sent]

# list of untagged words
validation_tagged_words = [tup[0] for sent in validation_set for tup in sent]
print(len(validation_set))
print(len(validation_tagged_words))
# Out:
# 196
# 5059

# %%
# %%time
# tagging the test sentences
start = time.time()
validation_Viterbi1 = Viterbi(validation_tagged_words)
end = time.time()
difference = end-start
# Out:
# CPU times: user 10min 46s, sys: 89.5 ms, total: 10min 46s
# Wall time: 10min 46s

# %%
# accuracy
check = [i for i, j in zip(validation_Viterbi1, validation_run_base) if i == j] 
accuracy = len(check)/len(validation_Viterbi1)

print(accuracy)
# Out:
# 0.9345720498122159

# %%
incorrect_tagged_cases = [[validation_run_base[i-1],j] for i, j in enumerate(zip(validation_Viterbi1, validation_run_base)) if j[0]!=j[1]]
print(incorrect_tagged_cases)
# Out:
# [[('regulated', 'VERB'), (('*-134', 'NOUN'), ('*-134', 'X'))], [('which', 'DET'), (('*T*-218', 'NOUN'), ('*T*-218', 'X'))], [('*T*-218', 'X'), (('reports', 'NOUN'), ('reports', 'VERB'))], [("'s", 'PRT'), (('floral', 'NOUN'), ('floral', 'ADJ'))], [('voters', 'NOUN'), (('disapprove', 'NOUN'), ('disapprove', 'VERB'))], [('had', 'VERB'), (('no', 'DET'), ('no', 'ADV'))], [('a', 'DET'), (('minimal', 'NOUN'), ('minimal', 'ADJ'))], [('$', '.'), (('7.2', 'NOUN'), ('7.2', 'NUM'))], [('.', '.'), (('Some', 'DET'), ('Some', 'ADV'))], [('to', 'PRT'), (('test', 'NOUN'), ('test', 'VERB'))], [('.', '.'), (('Most', 'ADJ'), ('Most', 'ADV'))], [('and', 'CONJ'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))], [('goverment', 'NOUN'), (('counts', 'NOUN'), ('counts', 'VERB'))], [('Dodge', 'NOUN'), (('counts', 'NOUN'), ('counts', 'VERB'))], [('a', 'DET'), (('first-time', 'NOUN'), ('first-time', 'ADJ'))], [('program', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))], [('that', 'DET'), (('*T*-99', 'NOUN'), ('*T*-99', 'X'))], [('have', 'VERB'), (('expunged', 'NOUN'), ('expunged', 'VERB'))], [('--', '.'), (('which', 'DET'), ('which', 'ADP'))], [('*T*-1', 'X'), (('earlier', 'ADV'), ('earlier', 'ADJ'))], [('--', '.'), (('agreed', 'VERB'), ('agreed', 'NOUN'))], [('to', 'PRT'), (('supply', 'NOUN'), ('supply', 'VERB'))], [('supply', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))], [('River', 'NOUN'), (('sank', 'NOUN'), ('sank', 'VERB'))], [('temporarily', 'ADV'), (('alleviate', 'NOUN'), ('alleviate', 'VERB'))], [('buy', 'VERB'), (('back', 'ADV'), ('back', 'PRT'))], [(',', '.'), (('notes', 'NOUN'), ('notes', 'VERB'))], [('55', 'NUM'), (('cents-a-unit', 'NOUN'), ('cents-a-unit', 'ADJ'))], [('is', 'VERB'), (('liquidated', 'NOUN'), ('liquidated', 'VERB'))], [('to', 'PRT'), (('bolster', 'NOUN'), ('bolster', 'VERB'))], [('$', '.'), (('18-a-share', 'NOUN'), ('18-a-share', 'ADJ'))], [('*U*', 'X'), (('offer', 'VERB'), ('offer', 'NOUN'))], [('are', 'VERB'), (('inching', 'NOUN'), ('inching', 'VERB'))], [('*', 'X'), (('labeling', 'NOUN'), ('labeling', 'VERB'))], [('for', 'ADP'), (('more', 'ADJ'), ('more', 'ADV'))], [('fully', 'ADV'), (('operational', 'NOUN'), ('operational', 'ADJ'))], [('who', 'PRON'), (('*T*-100', 'NOUN'), ('*T*-100', 'X'))], [('the', 'DET'), (('crib', 'ADJ'), ('crib', 'NOUN'))], [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))], [("'", 'PRT'), (('honor', 'VERB'), ('honor', 'NOUN'))], [('speedway', 'NOUN'), (('hauled', 'NOUN'), ('hauled', 'VERB'))], [('the', 'DET'), (('official', 'NOUN'), ('official', 'ADJ'))], [('a', 'DET'), (('10-lap', 'NOUN'), ('10-lap', 'ADJ'))], [('initial', 'ADJ'), (('public', 'NOUN'), ('public', 'ADJ'))], [('probably', 'ADV'), (('worth', 'ADJ'), ('worth', 'ADP'))], [('funds', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))], [('markets', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))], [('year', 'NOUN'), (('reversed', 'NOUN'), ('reversed', 'VERB'))], [('has', 'VERB'), (('chilled', 'NOUN'), ('chilled', 'VERB'))], [('$', '.'), (('114', 'NOUN'), ('114', 'NUM'))], [('areas', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))], [('that', 'DET'), (('*T*-186', 'NOUN'), ('*T*-186', 'X'))], [('plants', 'NOUN'), (('together', 'PRT'), ('together', 'ADV'))], [('will', 'VERB'), (('total', 'ADJ'), ('total', 'VERB'))], [('total', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))], [('$', '.'), (('280', 'NOUN'), ('280', 'NUM'))], [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))], [('product', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))], [('*T*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))], [('kids', 'NOUN'), (('broke', 'NOUN'), ('broke', 'VERB'))], [(',', '.'), (('traced', 'NOUN'), ('traced', 'VERB'))], [('of', 'ADP'), (('2163.2', 'NOUN'), ('2163.2', 'NUM'))], [('last', 'ADJ'), (('half-hour', 'ADJ'), ('half-hour', 'NOUN'))], [('is', 'VERB'), (('that', 'ADP'), ('that', 'DET'))], [('mean', 'VERB'), (('as', 'ADP'), ('as', 'ADV'))], [('GMAC', 'NOUN'), (('screened', 'NOUN'), ('screened', 'VERB'))], [('holders', 'NOUN'), (('more', 'ADV'), ('more', 'ADJ'))], [('`` ...

# %%
# %%time
## Testing
test_cases_shared = 'Android is a mobile operating system developed by Google. Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013. Google and Twitter made a deal in 2015 that gave Google access to Twitter\'s firehose. Twitter is an online news and social networking service on which users post and interact with messages known as tweets. Before entering politics, Donald Trump was a domineering businessman and a television personality. The 2018 FIFA World Cup is the 21st FIFA World Cup, an international football tournament contested once every four years. This is the first World Cup to be held in Eastern Europe and the 11th time that it has been held in Europe. Show me the cheapest round trips from Dallas to Atlanta. I would like to see flights from Denver to Philadelphia. Show me the price of the flights leaving Atlanta at about 3 in the afternoon and arriving in San Francisco. NASA invited social media users to experience the launch of ICESAT-2 Satellite.'
test_words = word_tokenize(test_cases_shared)

tagged_seq = Viterbi(test_words)
# Out:
# CPU times: user 23.4 s, sys: 12 ms, total: 23.4 s
# Wall time: 23.4 s

# %%
print(tagged_seq)
# Out:
# [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NOUN'), ('.', '.'), ('Android', 'NOUN'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NOUN'), ('worldwide', 'NOUN'), ('on', 'ADP'), ('smartphones', 'NOUN'), ('since', 'ADP'), ('2011', 'NOUN'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'NOUN'), ('.', '.'), ('Google', 'NOUN'), ('and', 'CONJ'), ('Twitter', 'NOUN'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'NOUN'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'NOUN'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'NOUN'), ("'s", 'PRT'), ('firehose', 'NOUN'), ('.', '.'), ('Twitter', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('online', 'NOUN'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'NOUN'), ('with', 'ADP'), ('messages', 'NOUN'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'NOUN'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'NOUN'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'NOUN'), ('.', '.'), ('The', 'DET'), ('2018', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'NOUN'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('.', '.'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'NOUN'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'NOUN'), ('invited', 'NOUN'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'NOUN'), ('Satellite', 'NOUN'), ('.', '.')]

# %%
## Modification -1: all unknown words are replaced by Noun (Noun being the most common tag)

def Viterbi_modf1(test_words, train_bag = train_set_words):
    tagged_seq = Viterbi(test_words)
    V = list(set([pair[0] for pair in train_bag]))
    
    words = [pair[0] for pair in tagged_seq]
    Viterbi_tags = [pair[1] for pair in tagged_seq]
    
    for key, word in enumerate(words):
        if word not in V:
            Viterbi_tags[key] = 'NOUN'
            
    
    return list(zip(words, Viterbi_tags))

# %%
# %%time
validation_Viterbimodf1 = Viterbi_modf1(validation_tagged_words)
# Out:
# CPU times: user 10min 40s, sys: 66 ms, total: 10min 40s
# Wall time: 10min 40s

# %%
check_modf1 = [i for i, j in zip(validation_Viterbimodf1, validation_run_base) if i == j] 
accuracy = len(check_modf1)/len(validation_Viterbimodf1)
accuracy
# Out:
# 0.9345720498122159

# %%
tagged_seq2_test = Viterbi_modf1(test_words)

# %%
validation_run_base_test
# Out:
# [('The', 'DET'),
#  ('futures', 'NOUN'),
#  ('industry', 'NOUN'),
#  ('is', 'VERB'),
#  ('regulated', 'VERB'),
#  ('*-134', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('Commodity', 'NOUN'),
#  ('Futures', 'NOUN'),
#  ('Trading', 'NOUN'),
#  ('Commission', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-218', 'X'),
#  ('reports', 'VERB'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('Agriculture', 'NOUN'),
#  ('committees', 'NOUN'),
#  ('in', 'ADP'),
#  ('both', 'DET'),
#  ('houses', 'NOUN'),
#  ('.', '.'),
#  ('Citizens', 'NOUN'),
#  ('in', 'ADP'),
#  ('Peninsula', 'NOUN'),
#  (',', '.'),
#  ('Ohio', 'NOUN'),
#  (',', '.'),
#  ('*-1', 'X'),
#  ('upset', 'VERB'),
#  ('over', 'ADP'),
#  ('changes', 'NOUN'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('bridge', 'NOUN'),
#  (',', '.'),
#  ('negotiated', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  (':', '.'),
#  ('The', 'DET'),
#  ('bottom', 'NOUN'),
#  ('half', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('railing', 'NOUN'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('type', 'NOUN'),
#  ('F', 'NOUN'),
#  (',', '.'),
#  ('while', 'ADP'),
#  ('the', 'DET'),
#  ('top', 'ADJ'),
#  ('half', 'NOUN'),
#  ('will', 'VERB'),
#  ('have', 'VERB'),
#  ('the', 'DET'),
#  ('old', 'ADJ'),
#  ('bridge', 'NOUN'),
#  ("'s", 'PRT'),
#  ('floral', 'ADJ'),
#  ('pattern', 'NOUN'),
#  ('.', '.'),
#  ('--', '.'),
#  ('The', 'DET'),
#  ('USIA', 'NOUN'),
#  ('said', 'VERB'),
#  ('that', 'ADP'),
#  (',', '.'),
#  ('on', 'ADP'),
#  ('reflection', 'NOUN'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('course', 'NOUN'),
#  ('I', 'PRON'),
#  ('could', 'VERB'),
#  ('print', 'VERB'),
#  ('anything', 'NOUN'),
#  ('0', 'X'),
#  ('I', 'PRON'),
#  ('could', 'VERB'),
#  ('get', 'VERB'),
#  ('my', 'PRON'),
#  ('hands', 'NOUN'),
#  ('on', 'ADP'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('While', 'ADP'),
#  ('a', 'DET'),
#  ('quarter', 'NOUN'),
#  ('of', 'ADP'),
#  ('black', 'ADJ'),
#  ('voters', 'NOUN'),
#  ('disapprove', 'VERB'),
#  ('of', 'ADP'),
#  ('Mr.', 'NOUN'),
#  ('Bush', 'NOUN'),
#  ("'s", 'PRT'),
#  ('handling', 'NOUN'),
#  ('of', 'ADP'),
#  ('his', 'PRON'),
#  ('job', 'NOUN'),
#  (',', '.'),
#  ('only', 'ADV'),
#  ('15', 'NUM'),
#  ('%', 'NOUN'),
#  ('have', 'VERB'),
#  ('a', 'DET'),
#  ('negative', 'ADJ'),
#  ('view', 'NOUN'),
#  ('of', 'ADP'),
#  ('his', 'PRON'),
#  ('spouse', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('But', 'CONJ'),
#  ('most', 'ADJ'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('index', 'NOUN'),
#  ('had', 'VERB'),
#  ('no', 'ADV'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('a', 'DET'),
#  ('minimal', 'ADJ'),
#  ('effect', 'NOUN'),
#  ('on', 'ADP'),
#  ('trade', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('insurer', 'NOUN'),
#  ("'s", 'PRT'),
#  ('earnings', 'NOUN'),
#  ('from', 'ADP'),
#  ('commercial', 'ADJ'),
#  ('property\\/casualty', 'NOUN'),
#  ('lines', 'NOUN'),
#  ('fell', 'VERB'),
#  ('59', 'NUM'),
#  ('%', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('latest', 'ADJ'),
#  ('quarter', 'NOUN'),
#  (',', '.'),
#  ('while', 'ADP'),
#  ('it', 'PRON'),
#  ('lost', 'VERB'),
#  ('$', '.'),
#  ('7.2', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('its', 'PRON'),
#  ('personal', 'ADJ'),
#  ('property\\/casualty', 'NOUN'),
#  ('business', 'NOUN'),
#  (',', '.'),
#  ('compared', 'VERB'),
#  ('with', 'ADP'),
#  ('earnings', 'NOUN'),
#  ('of', 'ADP'),
#  ('$', '.'),
#  ('6.1', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('a', 'DET'),
#  ('year', 'NOUN'),
#  ('ago', 'ADP'),
#  ('.', '.'),
#  ('Bramalea', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ('expects', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('complete', 'VERB'),
#  ('the', 'DET'),
#  ('issue', 'NOUN'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('end', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('month', 'NOUN'),
#  ('.', '.'),
#  ('Some', 'ADV'),
#  (',', '.'),
#  ('such', 'ADJ'),
#  ('as', 'ADP'),
#  ('traditional', 'ADJ'),
#  ('money', 'NOUN'),
#  ('manager', 'NOUN'),
#  ('Neuberger', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Berman', 'NOUN'),
#  (',', '.'),
#  ('have', 'VERB'),
#  ('taken', 'VERB'),
#  ('out', 'PRT'),
#  ('national', 'ADJ'),
#  ('newspaper', 'NOUN'),
#  ('advertisements', 'NOUN'),
#  ('demanding', 'VERB'),
#  ('that', 'ADP'),
#  ('market', 'NOUN'),
#  ('regulators', 'NOUN'),
#  ('``', '.'),
#  ('stop', 'VERB'),
#  ('the', 'DET'),
#  ('numbers', 'NOUN'),
#  ('racket', 'NOUN'),
#  ('on', 'ADP'),
#  ('Wall', 'NOUN'),
#  ('Street', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Some', 'DET'),
#  ('criminal', 'ADJ'),
#  ('lawyers', 'NOUN'),
#  ('speculated', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('IRS', 'NOUN'),
#  ('was', 'VERB'),
#  ('sending', 'VERB'),
#  ('the', 'DET'),
#  ('letters', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('test', 'VERB'),
#  ('the', 'DET'),
#  ('issue', 'NOUN'),
#  ('.', '.'),
#  ('Most', 'ADV'),
#  ('recently', 'ADV'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Veraldi', 'NOUN'),
#  (',', '.'),
#  ('59', 'NUM'),
#  ('years', 'NOUN'),
#  ('old', 'ADJ'),
#  (',', '.'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('vice', 'NOUN'),
#  ('president', 'NOUN'),
#  ('of', 'ADP'),
#  ('product', 'NOUN'),
#  ('and', 'CONJ'),
#  ('manufacturing', 'VERB'),
#  ('engineering', 'NOUN'),
#  ('at', 'ADP'),
#  ('Ford', 'NOUN'),
#  ('Motor', 'NOUN'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('goverment', 'NOUN'),
#  ('counts', 'VERB'),
#  ('money', 'NOUN'),
#  ('as', 'ADP'),
#  ('it', 'PRON'),
#  ('is', 'VERB'),
#  ('spent', 'VERB'),
#  ('*-53', 'X'),
#  (';', '.'),
#  ('Dodge', 'NOUN'),
#  ('counts', 'VERB'),
#  ('contracts', 'NOUN'),
#  ('when', 'ADV'),
#  ('they', 'PRON'),
#  ('are', 'VERB'),
#  ('awarded', 'VERB'),
#  ('*-54', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Partly', 'ADV'),
#  ('because', 'ADP'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('show', 'NOUN'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Watson', 'NOUN'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('district', 'NOUN'),
#  ('decided', 'VERB'),
#  ('not', 'ADV'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('recommend', 'VERB'),
#  ('Mrs.', 'NOUN'),
#  ('Yeargin', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('first-time', 'ADJ'),
#  ('offenders', 'NOUN'),
#  ('program', 'NOUN'),
#  ('that', 'DET'),
#  ('*T*-99', 'X'),
#  ('could', 'VERB'),
#  ('have', 'VERB'),
#  ('expunged', 'VERB'),
#  ('the', 'DET'),
#  ('charges', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('conviction', 'NOUN'),
#  ('from', 'ADP'),
#  ('her', 'PRON'),
#  ('record', 'NOUN'),
#  ('.', '.'),
#  ('Interpublic', 'NOUN'),
#  ('Group', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('its', 'PRON'),
#  ('television', 'NOUN'),
#  ('programming', 'NOUN'),
#  ('operations', 'NOUN'),
#  ('--', '.'),
#  ('which', 'ADP'),
#  ('it', 'PRON'),
#  ('expanded', 'VERB'),
#  ('*T*-1', 'X'),
#  ('earlier', 'ADJ'),
#  ('this', 'DET'),
#  ('year', 'NOUN'),
#  ('--', '.'),
#  ('agreed', 'NOUN'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('supply', 'VERB'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('4,000', 'NUM'),
#  ('hours', 'NOUN'),
#  ('of', 'ADP'),
#  ('original', 'ADJ'),
#  ('programming', 'NOUN'),
#  ('across', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('in', 'ADP'),
#  ('1990', 'NUM'),
#  ('.', '.'),
#  ('Each', 'DET'),
#  ('50,000', 'NUM'),
#  ('Swiss', 'ADJ'),
#  ('franc', 'NOUN'),
#  ('note', 'NOUN'),
#  ('is', 'VERB'),
#  ('convertible', 'ADJ'),
#  ('from', 'ADP'),
#  ('Nov.', 'NOUN'),
#  ('30', 'NUM'),
#  (',', '.'),
#  ('1989', 'NUM'),
#  (',', '.'),
#  ('to', 'PRT'),
#  ('March', 'NOUN'),
#  ('16', 'NUM'),
#  (',', '.'),
#  ('1994', 'NUM'),
#  ('at', 'ADP'),
#  ('a', 'DET'),
#  ('5', 'NUM'),
#  ('%', 'NOUN'),
#  ('premium', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('closing', 'ADJ'),
#  ('share', 'NOUN'),
#  ('price', 'NOUN'),
#  ('Monday', 'NOUN'),
#  (',', '.'),
#  ('when', 'ADV'),
#  ('terms', 'NOUN'),
#  ('are', 'VERB'),
#  ('scheduled', 'VERB'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('fixed', 'VERB'),
#  ('*-1', 'X'),
#  ('*T*-2', 'X'),
#  ('.', '.'),
#  ('Barge', 'NOUN'),
#  ('rates', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('Mississippi', 'NOUN'),
#  ('River', 'NOUN'),
#  ('sank', 'VERB'),
#  ('yesterday', 'NOUN'),
#  ('on', 'ADP'),
#  ('speculation', 'NOUN'),
#  ('that', 'ADP'),
#  ('widespread', 'ADJ'),
#  ('rain', 'NOUN'),
#  ('*ICH*-3', 'X'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('Midwest', 'NOUN'),
#  ('might', 'VERB'),
#  ('temporarily', 'ADV'),
#  ('alleviate', 'VERB'),
#  ('the', 'DET'),
#  ('situation', 'NOUN'),
#  ('.', '.'),
#  ('Neil', 'NOUN'),
#  ('Kuvin', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('general', 'ADJ'),
#  ('manager', 'NOUN'),
#  ('of', 'ADP'),
#  ('WHAS', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('CBS', 'NOUN'),
#  ('affiliate', 'NOUN'),
#  ('in', 'ADP'),
#  ('Louisville', 'NOUN'),
#  (',', '.'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('``', '.'),
#  ('Cosby', 'NOUN'),
#  ("''", '.'),
#  ('gets', 'VERB'),
#  ('the', 'DET'),
#  ('station', 'NOUN'),
#  ("'s", 'PRT'),
#  ('highest', 'ADJ'),
#  ('ratings', 'NOUN'),
#  ('and', 'CONJ'),
#  ('0', 'X'),
#  ('he', 'PRON'),
#  ("'s", 'VERB'),
#  ('``', '.'),
#  ('pleased', 'VERB'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Rather', 'ADV'),
#  ('than', 'ADP'),
#  ('*-1', 'X'),
#  ('increasing', 'VERB'),
#  ('dividends', 'NOUN'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('companies', 'NOUN'),
#  ('have', 'VERB'),
#  ('used', 'VERB'),
#  ('cash', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('buy', 'VERB'),
#  ('back', 'PRT'),
#  ('some', 'DET'),
#  ('of', 'ADP'),
#  ('their', 'PRON'),
#  ('shares', 'NOUN'),
#  (',', '.'),
#  ('notes', 'VERB'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('Steven', 'NOUN'),
#  ('G.', 'NOUN'),
#  ('Einhorn', 'NOUN'),
#  (',', '.'),
#  ('co-chairman', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('investment', 'NOUN'),
#  ('policy', 'NOUN'),
#  ('committee', 'NOUN'),
#  ('at', 'ADP'),
#  ('Goldman', 'NOUN'),
#  (',', '.'),
#  ('Sachs', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('Unitholders', 'NOUN'),
#  ('will', 'VERB'),
#  ('receive', 'VERB'),
#  ('two', 'NUM'),
#  ('additional', 'ADJ'),
#  ('55', 'NUM'),
#  ('cents-a-unit', 'ADJ'),
#  ('distribution', 'NOUN'),
#  ('payments', 'NOUN'),
#  ('before', 'ADP'),
#  ('the', 'DET'),
#  ('trust', 'NOUN'),
#  ('is', 'VERB'),
#  ('liquidated', 'VERB'),
#  ('*-1', 'X'),
#  ('in', 'ADP'),
#  ('early', 'ADJ'),
#  ('1990', 'NUM'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('.', '.'),
#  ('Prosecutors', 'NOUN'),
#  ('alleged', 'VERB'),
#  ('that', 'ADP'),
#  ('she', 'PRON'),
#  ('was', 'VERB'),
#  ('trying', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('bolster', 'VERB'),
#  ('students', 'NOUN'),
#  ("'", 'PRT'),
#  ('scores', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('win', 'VERB'),
#  ('a', 'DET'),
#  ('bonus', 'NOUN'),
#  ('under', 'ADP'),
#  ('the', 'DET'),
#  ('state', 'NOUN'),
#  ("'s", 'PRT'),
#  ('1984', 'NUM'),
#  ('Education', 'NOUN'),
#  ('Improvement', 'NOUN'),
#  ('Act', 'NOUN'),
#  ('.', '.'),
#  ('Dow', 'NOUN'),
#  ('Jones', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ('extended', 'VERB'),
#  ('its', 'PRON'),
#  ('$', '.'),
#  ('18-a-share', 'ADJ'),
#  ('*U*', 'X'),
#  ('offer', 'NOUN'),
#  ('for', 'ADP'),
#  ('Telerate', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  ('common', 'ADJ'),
#  ('stock', 'NOUN'),
#  ('until', 'ADP'),
#  ('5', 'NUM'),
#  ('p.m.', 'NOUN'),
#  ('EST', 'NOUN'),
#  ('Nov.', 'NOUN'),
#  ('9', 'NUM'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('Champagne', 'NOUN'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('prestige', 'NOUN'),
#  ('cuvees', 'NOUN'),
#  ('are', 'VERB'),
#  ('inching', 'VERB'),
#  ('toward', 'ADP'),
#  ('$', '.'),
#  ('100', 'NUM'),
#  ('*U*', 'X'),
#  ('a', 'DET'),
#  ('bottle', 'NOUN'),
#  ('.', '.'),
#  ('Your', 'PRON'),
#  ('research', 'NOUN'),
#  ('stopped', 'VERB'),
#  ('when', 'ADV'),
#  ('a', 'DET'),
#  ('convenient', 'ADJ'),
#  ('assertion', 'NOUN'),
#  ('could', 'VERB'),
#  ('be', 'VERB'),
#  ('made', 'VERB'),
#  ('*-22', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('We', 'PRON'),
#  ('must', 'VERB'),
#  ('be', 'VERB'),
#  ('very', 'ADV'),
#  ('cautious', 'ADJ'),
#  ('about', 'ADP'),
#  ('*', 'X'),
#  ('labeling', 'VERB'),
#  ('investors', 'NOUN'),
#  ('as', 'ADP'),
#  ('``', '.'),
#  ('long-term', 'ADJ'),
#  ("''", '.'),
#  ('or', 'CONJ'),
#  ('``', '.'),
#  ('short-term', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('documents', 'NOUN'),
#  ('also', 'ADV'),
#  ('said', 'VERB'),
#  ('that', 'ADP'),
#  ('although', 'ADP'),
#  ('the', 'DET'),
#  ('64-year-old', 'ADJ'),
#  ('Mr.', 'NOUN'),
#  ('Cray', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('working', 'VERB'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('project', 'NOUN'),
#  ('for', 'ADP'),
#  ('more', 'ADV'),
#  ('than', 'ADP'),
#  ('six', 'NUM'),
#  ('years', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Cray-3', 'NOUN'),
#  ('machine', 'NOUN'),
#  ('is', 'VERB'),
#  ('at', 'ADP'),
#  ('least', 'ADJ'),
#  ('another', 'DET'),
#  ('year', 'NOUN'),
#  ('away', 'ADV'),
#  ('from', 'ADP'),
#  ('a', 'DET'),
#  ('fully', 'ADV'),
#  ('operational', 'ADJ'),
#  ('prototype', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('plan', 'NOUN'),
#  ('relies', 'VERB'),
#  ('heavily', 'ADV'),
#  ('on', 'ADP'),
#  ('$', '.'),
#  ('240', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('credit', 'NOUN'),
#  ('and', 'CONJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('in', 'ADP'),
#  ('fiscal', 'ADJ'),
#  ('1990', 'NUM'),
#  ('in', 'ADP'),
#  ('hopes', 'NOUN'),
#  ('of', 'ADP'),
#  ('*', 'X'),
#  ('stimulating', 'VERB'),
#  ('future', 'ADJ'),
#  ('trade', 'NOUN'),
#  ('and', 'CONJ'),
#  ('investment', 'NOUN'),
#  ('.', '.')]

# %%
validation_run_base
# Out:
# [('The', 'DET'),
#  ('futures', 'NOUN'),
#  ('industry', 'NOUN'),
#  ('is', 'VERB'),
#  ('regulated', 'VERB'),
#  ('*-134', 'X'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('Commodity', 'NOUN'),
#  ('Futures', 'NOUN'),
#  ('Trading', 'NOUN'),
#  ('Commission', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-218', 'X'),
#  ('reports', 'VERB'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('Agriculture', 'NOUN'),
#  ('committees', 'NOUN'),
#  ('in', 'ADP'),
#  ('both', 'DET'),
#  ('houses', 'NOUN'),
#  ('.', '.'),
#  ('Citizens', 'NOUN'),
#  ('in', 'ADP'),
#  ('Peninsula', 'NOUN'),
#  (',', '.'),
#  ('Ohio', 'NOUN'),
#  (',', '.'),
#  ('*-1', 'X'),
#  ('upset', 'VERB'),
#  ('over', 'ADP'),
#  ('changes', 'NOUN'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('bridge', 'NOUN'),
#  (',', '.'),
#  ('negotiated', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  (':', '.'),
#  ('The', 'DET'),
#  ('bottom', 'NOUN'),
#  ('half', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('railing', 'NOUN'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('type', 'NOUN'),
#  ('F', 'NOUN'),
#  (',', '.'),
#  ('while', 'ADP'),
#  ('the', 'DET'),
#  ('top', 'ADJ'),
#  ('half', 'NOUN'),
#  ('will', 'VERB'),
#  ('have', 'VERB'),
#  ('the', 'DET'),
#  ('old', 'ADJ'),
#  ('bridge', 'NOUN'),
#  ("'s", 'PRT'),
#  ('floral', 'ADJ'),
#  ('pattern', 'NOUN'),
#  ('.', '.'),
#  ('--', '.'),
#  ('The', 'DET'),
#  ('USIA', 'NOUN'),
#  ('said', 'VERB'),
#  ('that', 'ADP'),
#  (',', '.'),
#  ('on', 'ADP'),
#  ('reflection', 'NOUN'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('course', 'NOUN'),
#  ('I', 'PRON'),
#  ('could', 'VERB'),
#  ('print', 'VERB'),
#  ('anything', 'NOUN'),
#  ('0', 'X'),
#  ('I', 'PRON'),
#  ('could', 'VERB'),
#  ('get', 'VERB'),
#  ('my', 'PRON'),
#  ('hands', 'NOUN'),
#  ('on', 'ADP'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('While', 'ADP'),
#  ('a', 'DET'),
#  ('quarter', 'NOUN'),
#  ('of', 'ADP'),
#  ('black', 'ADJ'),
#  ('voters', 'NOUN'),
#  ('disapprove', 'VERB'),
#  ('of', 'ADP'),
#  ('Mr.', 'NOUN'),
#  ('Bush', 'NOUN'),
#  ("'s", 'PRT'),
#  ('handling', 'NOUN'),
#  ('of', 'ADP'),
#  ('his', 'PRON'),
#  ('job', 'NOUN'),
#  (',', '.'),
#  ('only', 'ADV'),
#  ('15', 'NUM'),
#  ('%', 'NOUN'),
#  ('have', 'VERB'),
#  ('a', 'DET'),
#  ('negative', 'ADJ'),
#  ('view', 'NOUN'),
#  ('of', 'ADP'),
#  ('his', 'PRON'),
#  ('spouse', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('But', 'CONJ'),
#  ('most', 'ADJ'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('index', 'NOUN'),
#  ('had', 'VERB'),
#  ('no', 'ADV'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('a', 'DET'),
#  ('minimal', 'ADJ'),
#  ('effect', 'NOUN'),
#  ('on', 'ADP'),
#  ('trade', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('insurer', 'NOUN'),
#  ("'s", 'PRT'),
#  ('earnings', 'NOUN'),
#  ('from', 'ADP'),
#  ('commercial', 'ADJ'),
#  ('property\\/casualty', 'NOUN'),
#  ('lines', 'NOUN'),
#  ('fell', 'VERB'),
#  ('59', 'NUM'),
#  ('%', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('latest', 'ADJ'),
#  ('quarter', 'NOUN'),
#  (',', '.'),
#  ('while', 'ADP'),
#  ('it', 'PRON'),
#  ('lost', 'VERB'),
#  ('$', '.'),
#  ('7.2', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('its', 'PRON'),
#  ('personal', 'ADJ'),
#  ('property\\/casualty', 'NOUN'),
#  ('business', 'NOUN'),
#  (',', '.'),
#  ('compared', 'VERB'),
#  ('with', 'ADP'),
#  ('earnings', 'NOUN'),
#  ('of', 'ADP'),
#  ('$', '.'),
#  ('6.1', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('a', 'DET'),
#  ('year', 'NOUN'),
#  ('ago', 'ADP'),
#  ('.', '.'),
#  ('Bramalea', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ('expects', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('complete', 'VERB'),
#  ('the', 'DET'),
#  ('issue', 'NOUN'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('end', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('month', 'NOUN'),
#  ('.', '.'),
#  ('Some', 'ADV'),
#  (',', '.'),
#  ('such', 'ADJ'),
#  ('as', 'ADP'),
#  ('traditional', 'ADJ'),
#  ('money', 'NOUN'),
#  ('manager', 'NOUN'),
#  ('Neuberger', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Berman', 'NOUN'),
#  (',', '.'),
#  ('have', 'VERB'),
#  ('taken', 'VERB'),
#  ('out', 'PRT'),
#  ('national', 'ADJ'),
#  ('newspaper', 'NOUN'),
#  ('advertisements', 'NOUN'),
#  ('demanding', 'VERB'),
#  ('that', 'ADP'),
#  ('market', 'NOUN'),
#  ('regulators', 'NOUN'),
#  ('``', '.'),
#  ('stop', 'VERB'),
#  ('the', 'DET'),
#  ('numbers', 'NOUN'),
#  ('racket', 'NOUN'),
#  ('on', 'ADP'),
#  ('Wall', 'NOUN'),
#  ('Street', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Some', 'DET'),
#  ('criminal', 'ADJ'),
#  ('lawyers', 'NOUN'),
#  ('speculated', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('IRS', 'NOUN'),
#  ('was', 'VERB'),
#  ('sending', 'VERB'),
#  ('the', 'DET'),
#  ('letters', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('test', 'VERB'),
#  ('the', 'DET'),
#  ('issue', 'NOUN'),
#  ('.', '.'),
#  ('Most', 'ADV'),
#  ('recently', 'ADV'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Veraldi', 'NOUN'),
#  (',', '.'),
#  ('59', 'NUM'),
#  ('years', 'NOUN'),
#  ('old', 'ADJ'),
#  (',', '.'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('vice', 'NOUN'),
#  ('president', 'NOUN'),
#  ('of', 'ADP'),
#  ('product', 'NOUN'),
#  ('and', 'CONJ'),
#  ('manufacturing', 'VERB'),
#  ('engineering', 'NOUN'),
#  ('at', 'ADP'),
#  ('Ford', 'NOUN'),
#  ('Motor', 'NOUN'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('goverment', 'NOUN'),
#  ('counts', 'VERB'),
#  ('money', 'NOUN'),
#  ('as', 'ADP'),
#  ('it', 'PRON'),
#  ('is', 'VERB'),
#  ('spent', 'VERB'),
#  ('*-53', 'X'),
#  (';', '.'),
#  ('Dodge', 'NOUN'),
#  ('counts', 'VERB'),
#  ('contracts', 'NOUN'),
#  ('when', 'ADV'),
#  ('they', 'PRON'),
#  ('are', 'VERB'),
#  ('awarded', 'VERB'),
#  ('*-54', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Partly', 'ADV'),
#  ('because', 'ADP'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('show', 'NOUN'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Watson', 'NOUN'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('district', 'NOUN'),
#  ('decided', 'VERB'),
#  ('not', 'ADV'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('recommend', 'VERB'),
#  ('Mrs.', 'NOUN'),
#  ('Yeargin', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('first-time', 'ADJ'),
#  ('offenders', 'NOUN'),
#  ('program', 'NOUN'),
#  ('that', 'DET'),
#  ('*T*-99', 'X'),
#  ('could', 'VERB'),
#  ('have', 'VERB'),
#  ('expunged', 'VERB'),
#  ('the', 'DET'),
#  ('charges', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('conviction', 'NOUN'),
#  ('from', 'ADP'),
#  ('her', 'PRON'),
#  ('record', 'NOUN'),
#  ('.', '.'),
#  ('Interpublic', 'NOUN'),
#  ('Group', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('its', 'PRON'),
#  ('television', 'NOUN'),
#  ('programming', 'NOUN'),
#  ('operations', 'NOUN'),
#  ('--', '.'),
#  ('which', 'ADP'),
#  ('it', 'PRON'),
#  ('expanded', 'VERB'),
#  ('*T*-1', 'X'),
#  ('earlier', 'ADJ'),
#  ('this', 'DET'),
#  ('year', 'NOUN'),
#  ('--', '.'),
#  ('agreed', 'NOUN'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('supply', 'VERB'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('4,000', 'NUM'),
#  ('hours', 'NOUN'),
#  ('of', 'ADP'),
#  ('original', 'ADJ'),
#  ('programming', 'NOUN'),
#  ('across', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('in', 'ADP'),
#  ('1990', 'NUM'),
#  ('.', '.'),
#  ('Each', 'DET'),
#  ('50,000', 'NUM'),
#  ('Swiss', 'ADJ'),
#  ('franc', 'NOUN'),
#  ('note', 'NOUN'),
#  ('is', 'VERB'),
#  ('convertible', 'ADJ'),
#  ('from', 'ADP'),
#  ('Nov.', 'NOUN'),
#  ('30', 'NUM'),
#  (',', '.'),
#  ('1989', 'NUM'),
#  (',', '.'),
#  ('to', 'PRT'),
#  ('March', 'NOUN'),
#  ('16', 'NUM'),
#  (',', '.'),
#  ('1994', 'NUM'),
#  ('at', 'ADP'),
#  ('a', 'DET'),
#  ('5', 'NUM'),
#  ('%', 'NOUN'),
#  ('premium', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('closing', 'ADJ'),
#  ('share', 'NOUN'),
#  ('price', 'NOUN'),
#  ('Monday', 'NOUN'),
#  (',', '.'),
#  ('when', 'ADV'),
#  ('terms', 'NOUN'),
#  ('are', 'VERB'),
#  ('scheduled', 'VERB'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('fixed', 'VERB'),
#  ('*-1', 'X'),
#  ('*T*-2', 'X'),
#  ('.', '.'),
#  ('Barge', 'NOUN'),
#  ('rates', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('Mississippi', 'NOUN'),
#  ('River', 'NOUN'),
#  ('sank', 'VERB'),
#  ('yesterday', 'NOUN'),
#  ('on', 'ADP'),
#  ('speculation', 'NOUN'),
#  ('that', 'ADP'),
#  ('widespread', 'ADJ'),
#  ('rain', 'NOUN'),
#  ('*ICH*-3', 'X'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('Midwest', 'NOUN'),
#  ('might', 'VERB'),
#  ('temporarily', 'ADV'),
#  ('alleviate', 'VERB'),
#  ('the', 'DET'),
#  ('situation', 'NOUN'),
#  ('.', '.'),
#  ('Neil', 'NOUN'),
#  ('Kuvin', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('general', 'ADJ'),
#  ('manager', 'NOUN'),
#  ('of', 'ADP'),
#  ('WHAS', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('CBS', 'NOUN'),
#  ('affiliate', 'NOUN'),
#  ('in', 'ADP'),
#  ('Louisville', 'NOUN'),
#  (',', '.'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('``', '.'),
#  ('Cosby', 'NOUN'),
#  ("''", '.'),
#  ('gets', 'VERB'),
#  ('the', 'DET'),
#  ('station', 'NOUN'),
#  ("'s", 'PRT'),
#  ('highest', 'ADJ'),
#  ('ratings', 'NOUN'),
#  ('and', 'CONJ'),
#  ('0', 'X'),
#  ('he', 'PRON'),
#  ("'s", 'VERB'),
#  ('``', '.'),
#  ('pleased', 'VERB'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Rather', 'ADV'),
#  ('than', 'ADP'),
#  ('*-1', 'X'),
#  ('increasing', 'VERB'),
#  ('dividends', 'NOUN'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('companies', 'NOUN'),
#  ('have', 'VERB'),
#  ('used', 'VERB'),
#  ('cash', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('buy', 'VERB'),
#  ('back', 'PRT'),
#  ('some', 'DET'),
#  ('of', 'ADP'),
#  ('their', 'PRON'),
#  ('shares', 'NOUN'),
#  (',', '.'),
#  ('notes', 'VERB'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('Steven', 'NOUN'),
#  ('G.', 'NOUN'),
#  ('Einhorn', 'NOUN'),
#  (',', '.'),
#  ('co-chairman', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('investment', 'NOUN'),
#  ('policy', 'NOUN'),
#  ('committee', 'NOUN'),
#  ('at', 'ADP'),
#  ('Goldman', 'NOUN'),
#  (',', '.'),
#  ('Sachs', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('Unitholders', 'NOUN'),
#  ('will', 'VERB'),
#  ('receive', 'VERB'),
#  ('two', 'NUM'),
#  ('additional', 'ADJ'),
#  ('55', 'NUM'),
#  ('cents-a-unit', 'ADJ'),
#  ('distribution', 'NOUN'),
#  ('payments', 'NOUN'),
#  ('before', 'ADP'),
#  ('the', 'DET'),
#  ('trust', 'NOUN'),
#  ('is', 'VERB'),
#  ('liquidated', 'VERB'),
#  ('*-1', 'X'),
#  ('in', 'ADP'),
#  ('early', 'ADJ'),
#  ('1990', 'NUM'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('.', '.'),
#  ('Prosecutors', 'NOUN'),
#  ('alleged', 'VERB'),
#  ('that', 'ADP'),
#  ('she', 'PRON'),
#  ('was', 'VERB'),
#  ('trying', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('bolster', 'VERB'),
#  ('students', 'NOUN'),
#  ("'", 'PRT'),
#  ('scores', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('win', 'VERB'),
#  ('a', 'DET'),
#  ('bonus', 'NOUN'),
#  ('under', 'ADP'),
#  ('the', 'DET'),
#  ('state', 'NOUN'),
#  ("'s", 'PRT'),
#  ('1984', 'NUM'),
#  ('Education', 'NOUN'),
#  ('Improvement', 'NOUN'),
#  ('Act', 'NOUN'),
#  ('.', '.'),
#  ('Dow', 'NOUN'),
#  ('Jones', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ('extended', 'VERB'),
#  ('its', 'PRON'),
#  ('$', '.'),
#  ('18-a-share', 'ADJ'),
#  ('*U*', 'X'),
#  ('offer', 'NOUN'),
#  ('for', 'ADP'),
#  ('Telerate', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  ('common', 'ADJ'),
#  ('stock', 'NOUN'),
#  ('until', 'ADP'),
#  ('5', 'NUM'),
#  ('p.m.', 'NOUN'),
#  ('EST', 'NOUN'),
#  ('Nov.', 'NOUN'),
#  ('9', 'NUM'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('Champagne', 'NOUN'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('prestige', 'NOUN'),
#  ('cuvees', 'NOUN'),
#  ('are', 'VERB'),
#  ('inching', 'VERB'),
#  ('toward', 'ADP'),
#  ('$', '.'),
#  ('100', 'NUM'),
#  ('*U*', 'X'),
#  ('a', 'DET'),
#  ('bottle', 'NOUN'),
#  ('.', '.'),
#  ('Your', 'PRON'),
#  ('research', 'NOUN'),
#  ('stopped', 'VERB'),
#  ('when', 'ADV'),
#  ('a', 'DET'),
#  ('convenient', 'ADJ'),
#  ('assertion', 'NOUN'),
#  ('could', 'VERB'),
#  ('be', 'VERB'),
#  ('made', 'VERB'),
#  ('*-22', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('We', 'PRON'),
#  ('must', 'VERB'),
#  ('be', 'VERB'),
#  ('very', 'ADV'),
#  ('cautious', 'ADJ'),
#  ('about', 'ADP'),
#  ('*', 'X'),
#  ('labeling', 'VERB'),
#  ('investors', 'NOUN'),
#  ('as', 'ADP'),
#  ('``', '.'),
#  ('long-term', 'ADJ'),
#  ("''", '.'),
#  ('or', 'CONJ'),
#  ('``', '.'),
#  ('short-term', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('documents', 'NOUN'),
#  ('also', 'ADV'),
#  ('said', 'VERB'),
#  ('that', 'ADP'),
#  ('although', 'ADP'),
#  ('the', 'DET'),
#  ('64-year-old', 'ADJ'),
#  ('Mr.', 'NOUN'),
#  ('Cray', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('working', 'VERB'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('project', 'NOUN'),
#  ('for', 'ADP'),
#  ('more', 'ADV'),
#  ('than', 'ADP'),
#  ('six', 'NUM'),
#  ('years', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Cray-3', 'NOUN'),
#  ('machine', 'NOUN'),
#  ('is', 'VERB'),
#  ('at', 'ADP'),
#  ('least', 'ADJ'),
#  ('another', 'DET'),
#  ('year', 'NOUN'),
#  ('away', 'ADV'),
#  ('from', 'ADP'),
#  ('a', 'DET'),
#  ('fully', 'ADV'),
#  ('operational', 'ADJ'),
#  ('prototype', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('plan', 'NOUN'),
#  ('relies', 'VERB'),
#  ('heavily', 'ADV'),
#  ('on', 'ADP'),
#  ('$', '.'),
#  ('240', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('credit', 'NOUN'),
#  ('and', 'CONJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('in', 'ADP'),
#  ('fiscal', 'ADJ'),
#  ('1990', 'NUM'),
#  ('in', 'ADP'),
#  ('hopes', 'NOUN'),
#  ('of', 'ADP'),
#  ('*', 'X'),
#  ('stimulating', 'VERB'),
#  ('future', 'ADJ'),
#  ('trade', 'NOUN'),
#  ('and', 'CONJ'),
#  ('investment', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('She', 'PRON'),
#  ('did', 'VERB'),
#  ('a', 'DET'),
#  ('lot', 'NOUN'),
#  ('of', 'ADP'),
#  ('harm', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Cathryn', 'NOUN'),
#  ('Rice', 'NOUN'),
#  (',', '.'),
#  ('who', 'PRON'),
#  ('*T*-100', 'X'),
#  ('had', 'VERB'),
#  ('discovered', 'VERB'),
#  ('the', 'DET'),
#  ('crib', 'NOUN'),
#  ('notes', 'NOUN'),
#  ('.', '.'),
#  ('Biscayne', 'NOUN'),
#  ('has', 'VERB'),
#  ("n't", 'ADV'),
#  ('any', 'DET'),
#  ('telephone', 'NOUN'),
#  ('listing', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('operator', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Moreover', 'ADV'),
#  (',', '.'),
#  ('we', 'PRON'),
#  ("'ve", 'VERB'),
#  ('probably', 'ADV'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('most', 'ADV'),
#  ('aggressive', 'ADJ'),
#  ('firm', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('Street', 'NOUN'),
#  ('in', 'ADP'),
#  ('*', 'X'),
#  ('reducing', 'VERB'),
#  ('costs', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-1', 'X'),
#  ('are', 'VERB'),
#  ('down', 'ADV'),
#  ('around', 'ADP'),
#  ('40', 'NUM'),
#  ('%', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('last', 'ADJ'),
#  ('six', 'NUM'),
#  ('months', 'NOUN'),
#  ('.', '.'),
#  ('Then', 'ADV'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('guests', 'NOUN'),
#  ("'", 'PRT'),
#  ('honor', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('speedway', 'NOUN'),
#  ('hauled', 'VERB'),
#  ('out', 'PRT'),
#  ('four', 'NUM'),
#  ('drivers', 'NOUN'),
#  (',', '.'),
#  ('crews', 'NOUN'),
#  ('and', 'CONJ'),
#  ('even', 'ADV'),
#  ('the', 'DET'),
#  ('official', 'ADJ'),
#  ('Indianapolis', 'NOUN'),
#  ('500', 'NUM'),
#  ('announcer', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('10-lap', 'ADJ'),
#  ('exhibition', 'NOUN'),
#  ('race', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('sale', 'NOUN'),
#  ('comes', 'VERB'),
#  ('in', 'ADP'),
#  ('place', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('planned', 'VERB'),
#  ('initial', 'ADJ'),
#  ('public', 'ADJ'),
#  ('offering', 'NOUN'),
#  ('of', 'ADP'),
#  ('Lentjes', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('.', '.'),
#  ('I', 'PRON'),
#  ('say', 'VERB'),
#  ('``', '.'),
#  ('*', 'X'),
#  ('contained', 'VERB'),
#  ('dialogue', 'NOUN'),
#  ("''", '.'),
#  ('because', 'ADP'),
#  ('``', '.'),
#  ('Sidewalk', 'NOUN'),
#  ('Stories', 'NOUN'),
#  ("''", '.'),
#  ('is', 'VERB'),
#  ("n't", 'ADV'),
#  ('really', 'ADV'),
#  ('silent', 'ADJ'),
#  ('at', 'ADP'),
#  ('all', 'DET'),
#  ('.', '.'),
#  ('It', 'PRON'),
#  ("'s", 'VERB'),
#  ('probably', 'ADV'),
#  ('worth', 'ADP'),
#  ('*', 'X'),
#  ('paying', 'VERB'),
#  ('a', 'DET'),
#  ('premium', 'NOUN'),
#  ('for', 'ADP'),
#  ('funds', 'NOUN'),
#  ('that', 'DET'),
#  ('*T*-42', 'X'),
#  ('invest', 'VERB'),
#  ('in', 'ADP'),
#  ('markets', 'NOUN'),
#  ('that', 'DET'),
#  ('*T*-43', 'X'),
#  ('are', 'VERB'),
#  ('partially', 'ADV'),
#  ('closed', 'VERB'),
#  ('to', 'PRT'),
#  ('foreign', 'ADJ'),
#  ('investors', 'NOUN'),
#  (',', '.'),
#  ('such', 'ADJ'),
#  ('as', 'ADP'),
#  ('South', 'NOUN'),
#  ('Korea', 'NOUN'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('specialists', 'NOUN'),
#  ('say', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('California', 'NOUN'),
#  ('Supreme', 'NOUN'),
#  ('Court', 'NOUN'),
#  ('last', 'ADJ'),
#  ('year', 'NOUN'),
#  ('reversed', 'VERB'),
#  ('direction', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('make', 'VERB'),
#  ('it', 'PRON'),
#  ('*EXP*-2', 'X'),
#  ('much', 'ADV'),
#  ('harder', 'ADJ'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('win', 'VERB'),
#  ('DES', 'NOUN'),
#  ('cases', 'NOUN'),
#  ('because', 'ADP'),
#  ('the', 'DET'),
#  ('justices', 'NOUN'),
#  ('saw', 'VERB'),
#  ('how', 'ADV'),
#  ('all', 'DET'),
#  ('the', 'DET'),
#  ('pharmaceutical', 'ADJ'),
#  ('litigation', 'NOUN'),
#  ('has', 'VERB'),
#  ('chilled', 'VERB'),
#  ('the', 'DET'),
#  ('introduction', 'NOUN'),
#  ('of', 'ADP'),
#  ('new', 'ADJ'),
#  ('drugs', 'NOUN'),
#  ('*T*-3', 'X'),
#  ('.', '.'),
#  ('A', 'DET'),
#  ('$', '.'),
#  ('114', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('issue', 'NOUN'),
#  ('of', 'ADP'),
#  ('health', 'NOUN'),
#  ('facility', 'NOUN'),
#  ('revenue', 'NOUN'),
#  ('bonds', 'NOUN'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('California', 'NOUN'),
#  ('Health', 'NOUN'),
#  ('Facilities', 'NOUN'),
#  ('Financing', 'NOUN'),
#  ('Authority', 'NOUN'),
#  ('was', 'VERB'),
#  ('temporarily', 'ADV'),
#  ('withdrawn', 'VERB'),
#  ('*-1', 'X'),
#  ('after', 'ADP'),
#  ('*-1', 'X'),
#  ('being', 'VERB'),
#  ('tentatively', 'ADV'),
#  ('priced', 'VERB'),
#  ('*-2', 'X'),
#  ('by', 'ADP'),
#  ('a', 'DET'),
#  ('First', 'NOUN'),
#  ('Boston', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('group', 'NOUN'),
#  ('.', '.'),
#  ('There', 'DET'),
#  ("'s", 'VERB'),
#  ('never', 'ADV'),
#  ('been', 'VERB'),
#  ('an', 'DET'),
#  ('exception', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('Gerald', 'NOUN'),
#  ('W.', 'NOUN'),
#  ('Perritt', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('Chicago', 'NOUN'),
#  ('investment', 'NOUN'),
#  ('adviser', 'NOUN'),
#  ('and', 'CONJ'),
#  ('money', 'NOUN'),
#  ('manager', 'NOUN'),
#  (',', '.'),
#  ('based', 'VERB'),
#  ('on', 'ADP'),
#  ('a', 'DET'),
#  ('review', 'NOUN'),
#  ('of', 'ADP'),
#  ('six', 'NUM'),
#  ('decades', 'NOUN'),
#  ('of', 'ADP'),
#  ('stock-market', 'NOUN'),
#  ('data', 'NOUN'),
#  ('.', '.'),
#  ('A', 'DET'),
#  ('look', 'NOUN'),
#  ('at', 'ADP'),
#  ('a', 'DET'),
#  ('Thursday', 'NOUN'),
#  ('night', 'NOUN'),
#  ('practice', 'NOUN'),
#  ('at', 'ADP'),
#  ('St.', 'NOUN'),
#  ('Mary', 'NOUN'),
#  ('Abbot', 'NOUN'),
#  ('church', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('Kensington', 'NOUN'),
#  ('district', 'NOUN'),
#  ('of', 'ADP'),
#  ('London', 'NOUN'),
#  ('gives', 'VERB'),
#  ('an', 'DET'),
#  ('idea', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('work', 'NOUN'),
#  ('involved', 'VERB'),
#  ('*', 'X'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('I', 'PRON'),
#  ('--', '.'),
#  ('I', 'PRON'),
#  ('like', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('think', 'VERB'),
#  ('of', 'ADP'),
#  ('it', 'PRON'),
#  ('in', 'ADP'),
#  ('terms', 'NOUN'),
#  ('of', 'ADP'),
#  ('we', 'PRON'),
#  (',', '.'),
#  ('all', 'DET'),
#  ...]

# %%
validation_Viterbi1
# Out:
# [('The', 'DET'),
#  ('futures', 'NOUN'),
#  ('industry', 'NOUN'),
#  ('is', 'VERB'),
#  ('regulated', 'VERB'),
#  ('*-134', 'NOUN'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('Commodity', 'NOUN'),
#  ('Futures', 'NOUN'),
#  ('Trading', 'NOUN'),
#  ('Commission', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-218', 'NOUN'),
#  ('reports', 'NOUN'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('Agriculture', 'NOUN'),
#  ('committees', 'NOUN'),
#  ('in', 'ADP'),
#  ('both', 'DET'),
#  ('houses', 'NOUN'),
#  ('.', '.'),
#  ('Citizens', 'NOUN'),
#  ('in', 'ADP'),
#  ('Peninsula', 'NOUN'),
#  (',', '.'),
#  ('Ohio', 'NOUN'),
#  (',', '.'),
#  ('*-1', 'X'),
#  ('upset', 'VERB'),
#  ('over', 'ADP'),
#  ('changes', 'NOUN'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('bridge', 'NOUN'),
#  (',', '.'),
#  ('negotiated', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  (':', '.'),
#  ('The', 'DET'),
#  ('bottom', 'NOUN'),
#  ('half', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('railing', 'NOUN'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('type', 'NOUN'),
#  ('F', 'NOUN'),
#  (',', '.'),
#  ('while', 'ADP'),
#  ('the', 'DET'),
#  ('top', 'ADJ'),
#  ('half', 'NOUN'),
#  ('will', 'VERB'),
#  ('have', 'VERB'),
#  ('the', 'DET'),
#  ('old', 'ADJ'),
#  ('bridge', 'NOUN'),
#  ("'s", 'PRT'),
#  ('floral', 'NOUN'),
#  ('pattern', 'NOUN'),
#  ('.', '.'),
#  ('--', '.'),
#  ('The', 'DET'),
#  ('USIA', 'NOUN'),
#  ('said', 'VERB'),
#  ('that', 'ADP'),
#  (',', '.'),
#  ('on', 'ADP'),
#  ('reflection', 'NOUN'),
#  (',', '.'),
#  ('of', 'ADP'),
#  ('course', 'NOUN'),
#  ('I', 'PRON'),
#  ('could', 'VERB'),
#  ('print', 'VERB'),
#  ('anything', 'NOUN'),
#  ('0', 'X'),
#  ('I', 'PRON'),
#  ('could', 'VERB'),
#  ('get', 'VERB'),
#  ('my', 'PRON'),
#  ('hands', 'NOUN'),
#  ('on', 'ADP'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('While', 'ADP'),
#  ('a', 'DET'),
#  ('quarter', 'NOUN'),
#  ('of', 'ADP'),
#  ('black', 'ADJ'),
#  ('voters', 'NOUN'),
#  ('disapprove', 'NOUN'),
#  ('of', 'ADP'),
#  ('Mr.', 'NOUN'),
#  ('Bush', 'NOUN'),
#  ("'s", 'PRT'),
#  ('handling', 'NOUN'),
#  ('of', 'ADP'),
#  ('his', 'PRON'),
#  ('job', 'NOUN'),
#  (',', '.'),
#  ('only', 'ADV'),
#  ('15', 'NUM'),
#  ('%', 'NOUN'),
#  ('have', 'VERB'),
#  ('a', 'DET'),
#  ('negative', 'ADJ'),
#  ('view', 'NOUN'),
#  ('of', 'ADP'),
#  ('his', 'PRON'),
#  ('spouse', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('But', 'CONJ'),
#  ('most', 'ADJ'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('index', 'NOUN'),
#  ('had', 'VERB'),
#  ('no', 'DET'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('a', 'DET'),
#  ('minimal', 'NOUN'),
#  ('effect', 'NOUN'),
#  ('on', 'ADP'),
#  ('trade', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('insurer', 'NOUN'),
#  ("'s", 'PRT'),
#  ('earnings', 'NOUN'),
#  ('from', 'ADP'),
#  ('commercial', 'ADJ'),
#  ('property\\/casualty', 'NOUN'),
#  ('lines', 'NOUN'),
#  ('fell', 'VERB'),
#  ('59', 'NUM'),
#  ('%', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('latest', 'ADJ'),
#  ('quarter', 'NOUN'),
#  (',', '.'),
#  ('while', 'ADP'),
#  ('it', 'PRON'),
#  ('lost', 'VERB'),
#  ('$', '.'),
#  ('7.2', 'NOUN'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('its', 'PRON'),
#  ('personal', 'ADJ'),
#  ('property\\/casualty', 'NOUN'),
#  ('business', 'NOUN'),
#  (',', '.'),
#  ('compared', 'VERB'),
#  ('with', 'ADP'),
#  ('earnings', 'NOUN'),
#  ('of', 'ADP'),
#  ('$', '.'),
#  ('6.1', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('a', 'DET'),
#  ('year', 'NOUN'),
#  ('ago', 'ADP'),
#  ('.', '.'),
#  ('Bramalea', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ('expects', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('complete', 'VERB'),
#  ('the', 'DET'),
#  ('issue', 'NOUN'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('end', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('month', 'NOUN'),
#  ('.', '.'),
#  ('Some', 'DET'),
#  (',', '.'),
#  ('such', 'ADJ'),
#  ('as', 'ADP'),
#  ('traditional', 'ADJ'),
#  ('money', 'NOUN'),
#  ('manager', 'NOUN'),
#  ('Neuberger', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Berman', 'NOUN'),
#  (',', '.'),
#  ('have', 'VERB'),
#  ('taken', 'VERB'),
#  ('out', 'PRT'),
#  ('national', 'ADJ'),
#  ('newspaper', 'NOUN'),
#  ('advertisements', 'NOUN'),
#  ('demanding', 'VERB'),
#  ('that', 'ADP'),
#  ('market', 'NOUN'),
#  ('regulators', 'NOUN'),
#  ('``', '.'),
#  ('stop', 'VERB'),
#  ('the', 'DET'),
#  ('numbers', 'NOUN'),
#  ('racket', 'NOUN'),
#  ('on', 'ADP'),
#  ('Wall', 'NOUN'),
#  ('Street', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Some', 'DET'),
#  ('criminal', 'ADJ'),
#  ('lawyers', 'NOUN'),
#  ('speculated', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('IRS', 'NOUN'),
#  ('was', 'VERB'),
#  ('sending', 'VERB'),
#  ('the', 'DET'),
#  ('letters', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('test', 'NOUN'),
#  ('the', 'DET'),
#  ('issue', 'NOUN'),
#  ('.', '.'),
#  ('Most', 'ADJ'),
#  ('recently', 'ADV'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Veraldi', 'NOUN'),
#  (',', '.'),
#  ('59', 'NUM'),
#  ('years', 'NOUN'),
#  ('old', 'ADJ'),
#  (',', '.'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('vice', 'NOUN'),
#  ('president', 'NOUN'),
#  ('of', 'ADP'),
#  ('product', 'NOUN'),
#  ('and', 'CONJ'),
#  ('manufacturing', 'NOUN'),
#  ('engineering', 'NOUN'),
#  ('at', 'ADP'),
#  ('Ford', 'NOUN'),
#  ('Motor', 'NOUN'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('goverment', 'NOUN'),
#  ('counts', 'NOUN'),
#  ('money', 'NOUN'),
#  ('as', 'ADP'),
#  ('it', 'PRON'),
#  ('is', 'VERB'),
#  ('spent', 'VERB'),
#  ('*-53', 'X'),
#  (';', '.'),
#  ('Dodge', 'NOUN'),
#  ('counts', 'NOUN'),
#  ('contracts', 'NOUN'),
#  ('when', 'ADV'),
#  ('they', 'PRON'),
#  ('are', 'VERB'),
#  ('awarded', 'VERB'),
#  ('*-54', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Partly', 'ADV'),
#  ('because', 'ADP'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('show', 'NOUN'),
#  (',', '.'),
#  ('Mr.', 'NOUN'),
#  ('Watson', 'NOUN'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('district', 'NOUN'),
#  ('decided', 'VERB'),
#  ('not', 'ADV'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('recommend', 'VERB'),
#  ('Mrs.', 'NOUN'),
#  ('Yeargin', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('first-time', 'NOUN'),
#  ('offenders', 'NOUN'),
#  ('program', 'NOUN'),
#  ('that', 'ADP'),
#  ('*T*-99', 'NOUN'),
#  ('could', 'VERB'),
#  ('have', 'VERB'),
#  ('expunged', 'NOUN'),
#  ('the', 'DET'),
#  ('charges', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('conviction', 'NOUN'),
#  ('from', 'ADP'),
#  ('her', 'PRON'),
#  ('record', 'NOUN'),
#  ('.', '.'),
#  ('Interpublic', 'NOUN'),
#  ('Group', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('its', 'PRON'),
#  ('television', 'NOUN'),
#  ('programming', 'NOUN'),
#  ('operations', 'NOUN'),
#  ('--', '.'),
#  ('which', 'DET'),
#  ('it', 'PRON'),
#  ('expanded', 'VERB'),
#  ('*T*-1', 'X'),
#  ('earlier', 'ADV'),
#  ('this', 'DET'),
#  ('year', 'NOUN'),
#  ('--', '.'),
#  ('agreed', 'VERB'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('supply', 'NOUN'),
#  ('more', 'ADV'),
#  ('than', 'ADP'),
#  ('4,000', 'NUM'),
#  ('hours', 'NOUN'),
#  ('of', 'ADP'),
#  ('original', 'ADJ'),
#  ('programming', 'NOUN'),
#  ('across', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('in', 'ADP'),
#  ('1990', 'NUM'),
#  ('.', '.'),
#  ('Each', 'DET'),
#  ('50,000', 'NUM'),
#  ('Swiss', 'ADJ'),
#  ('franc', 'NOUN'),
#  ('note', 'NOUN'),
#  ('is', 'VERB'),
#  ('convertible', 'ADJ'),
#  ('from', 'ADP'),
#  ('Nov.', 'NOUN'),
#  ('30', 'NUM'),
#  (',', '.'),
#  ('1989', 'NUM'),
#  (',', '.'),
#  ('to', 'PRT'),
#  ('March', 'NOUN'),
#  ('16', 'NUM'),
#  (',', '.'),
#  ('1994', 'NUM'),
#  ('at', 'ADP'),
#  ('a', 'DET'),
#  ('5', 'NUM'),
#  ('%', 'NOUN'),
#  ('premium', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('closing', 'ADJ'),
#  ('share', 'NOUN'),
#  ('price', 'NOUN'),
#  ('Monday', 'NOUN'),
#  (',', '.'),
#  ('when', 'ADV'),
#  ('terms', 'NOUN'),
#  ('are', 'VERB'),
#  ('scheduled', 'VERB'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('fixed', 'VERB'),
#  ('*-1', 'X'),
#  ('*T*-2', 'X'),
#  ('.', '.'),
#  ('Barge', 'NOUN'),
#  ('rates', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('Mississippi', 'NOUN'),
#  ('River', 'NOUN'),
#  ('sank', 'NOUN'),
#  ('yesterday', 'NOUN'),
#  ('on', 'ADP'),
#  ('speculation', 'NOUN'),
#  ('that', 'ADP'),
#  ('widespread', 'ADJ'),
#  ('rain', 'NOUN'),
#  ('*ICH*-3', 'X'),
#  ('this', 'DET'),
#  ('week', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('Midwest', 'NOUN'),
#  ('might', 'VERB'),
#  ('temporarily', 'ADV'),
#  ('alleviate', 'NOUN'),
#  ('the', 'DET'),
#  ('situation', 'NOUN'),
#  ('.', '.'),
#  ('Neil', 'NOUN'),
#  ('Kuvin', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('general', 'ADJ'),
#  ('manager', 'NOUN'),
#  ('of', 'ADP'),
#  ('WHAS', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('CBS', 'NOUN'),
#  ('affiliate', 'NOUN'),
#  ('in', 'ADP'),
#  ('Louisville', 'NOUN'),
#  (',', '.'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('``', '.'),
#  ('Cosby', 'NOUN'),
#  ("''", '.'),
#  ('gets', 'VERB'),
#  ('the', 'DET'),
#  ('station', 'NOUN'),
#  ("'s", 'PRT'),
#  ('highest', 'ADJ'),
#  ('ratings', 'NOUN'),
#  ('and', 'CONJ'),
#  ('0', 'X'),
#  ('he', 'PRON'),
#  ("'s", 'VERB'),
#  ('``', '.'),
#  ('pleased', 'VERB'),
#  ('*-1', 'X'),
#  ('.', '.'),
#  ("''", '.'),
#  ('Rather', 'ADV'),
#  ('than', 'ADP'),
#  ('*-1', 'X'),
#  ('increasing', 'VERB'),
#  ('dividends', 'NOUN'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('companies', 'NOUN'),
#  ('have', 'VERB'),
#  ('used', 'VERB'),
#  ('cash', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('buy', 'VERB'),
#  ('back', 'ADV'),
#  ('some', 'DET'),
#  ('of', 'ADP'),
#  ('their', 'PRON'),
#  ('shares', 'NOUN'),
#  (',', '.'),
#  ('notes', 'NOUN'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('Steven', 'NOUN'),
#  ('G.', 'NOUN'),
#  ('Einhorn', 'NOUN'),
#  (',', '.'),
#  ('co-chairman', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('investment', 'NOUN'),
#  ('policy', 'NOUN'),
#  ('committee', 'NOUN'),
#  ('at', 'ADP'),
#  ('Goldman', 'NOUN'),
#  (',', '.'),
#  ('Sachs', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co', 'NOUN'),
#  ('.', '.'),
#  ('Unitholders', 'NOUN'),
#  ('will', 'VERB'),
#  ('receive', 'VERB'),
#  ('two', 'NUM'),
#  ('additional', 'ADJ'),
#  ('55', 'NUM'),
#  ('cents-a-unit', 'NOUN'),
#  ('distribution', 'NOUN'),
#  ('payments', 'NOUN'),
#  ('before', 'ADP'),
#  ('the', 'DET'),
#  ('trust', 'NOUN'),
#  ('is', 'VERB'),
#  ('liquidated', 'NOUN'),
#  ('*-1', 'X'),
#  ('in', 'ADP'),
#  ('early', 'ADJ'),
#  ('1990', 'NUM'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('.', '.'),
#  ('Prosecutors', 'NOUN'),
#  ('alleged', 'VERB'),
#  ('that', 'ADP'),
#  ('she', 'PRON'),
#  ('was', 'VERB'),
#  ('trying', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('bolster', 'NOUN'),
#  ('students', 'NOUN'),
#  ("'", 'PRT'),
#  ('scores', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('win', 'VERB'),
#  ('a', 'DET'),
#  ('bonus', 'NOUN'),
#  ('under', 'ADP'),
#  ('the', 'DET'),
#  ('state', 'NOUN'),
#  ("'s", 'PRT'),
#  ('1984', 'NUM'),
#  ('Education', 'NOUN'),
#  ('Improvement', 'NOUN'),
#  ('Act', 'NOUN'),
#  ('.', '.'),
#  ('Dow', 'NOUN'),
#  ('Jones', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Co.', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ('extended', 'VERB'),
#  ('its', 'PRON'),
#  ('$', '.'),
#  ('18-a-share', 'NOUN'),
#  ('*U*', 'X'),
#  ('offer', 'VERB'),
#  ('for', 'ADP'),
#  ('Telerate', 'NOUN'),
#  ('Inc.', 'NOUN'),
#  ('common', 'ADJ'),
#  ('stock', 'NOUN'),
#  ('until', 'ADP'),
#  ('5', 'NUM'),
#  ('p.m.', 'NOUN'),
#  ('EST', 'NOUN'),
#  ('Nov.', 'NOUN'),
#  ('9', 'NUM'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('Champagne', 'NOUN'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('prestige', 'NOUN'),
#  ('cuvees', 'NOUN'),
#  ('are', 'VERB'),
#  ('inching', 'NOUN'),
#  ('toward', 'ADP'),
#  ('$', '.'),
#  ('100', 'NUM'),
#  ('*U*', 'X'),
#  ('a', 'DET'),
#  ('bottle', 'NOUN'),
#  ('.', '.'),
#  ('Your', 'PRON'),
#  ('research', 'NOUN'),
#  ('stopped', 'VERB'),
#  ('when', 'ADV'),
#  ('a', 'DET'),
#  ('convenient', 'ADJ'),
#  ('assertion', 'NOUN'),
#  ('could', 'VERB'),
#  ('be', 'VERB'),
#  ('made', 'VERB'),
#  ('*-22', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('We', 'PRON'),
#  ('must', 'VERB'),
#  ('be', 'VERB'),
#  ('very', 'ADV'),
#  ('cautious', 'ADJ'),
#  ('about', 'ADP'),
#  ('*', 'X'),
#  ('labeling', 'NOUN'),
#  ('investors', 'NOUN'),
#  ('as', 'ADP'),
#  ('``', '.'),
#  ('long-term', 'ADJ'),
#  ("''", '.'),
#  ('or', 'CONJ'),
#  ('``', '.'),
#  ('short-term', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('documents', 'NOUN'),
#  ('also', 'ADV'),
#  ('said', 'VERB'),
#  ('that', 'ADP'),
#  ('although', 'ADP'),
#  ('the', 'DET'),
#  ('64-year-old', 'ADJ'),
#  ('Mr.', 'NOUN'),
#  ('Cray', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('working', 'VERB'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('project', 'NOUN'),
#  ('for', 'ADP'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('six', 'NUM'),
#  ('years', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('Cray-3', 'NOUN'),
#  ('machine', 'NOUN'),
#  ('is', 'VERB'),
#  ('at', 'ADP'),
#  ('least', 'ADJ'),
#  ('another', 'DET'),
#  ('year', 'NOUN'),
#  ('away', 'ADV'),
#  ('from', 'ADP'),
#  ('a', 'DET'),
#  ('fully', 'ADV'),
#  ('operational', 'NOUN'),
#  ('prototype', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('plan', 'NOUN'),
#  ('relies', 'VERB'),
#  ('heavily', 'ADV'),
#  ('on', 'ADP'),
#  ('$', '.'),
#  ('240', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('in', 'ADP'),
#  ('credit', 'NOUN'),
#  ('and', 'CONJ'),
#  ('loan', 'NOUN'),
#  ('guarantees', 'NOUN'),
#  ('in', 'ADP'),
#  ('fiscal', 'ADJ'),
#  ('1990', 'NUM'),
#  ('in', 'ADP'),
#  ('hopes', 'NOUN'),
#  ('of', 'ADP'),
#  ('*', 'X'),
#  ('stimulating', 'VERB'),
#  ('future', 'ADJ'),
#  ('trade', 'NOUN'),
#  ('and', 'CONJ'),
#  ('investment', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('She', 'PRON'),
#  ('did', 'VERB'),
#  ('a', 'DET'),
#  ('lot', 'NOUN'),
#  ('of', 'ADP'),
#  ('harm', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Cathryn', 'NOUN'),
#  ('Rice', 'NOUN'),
#  (',', '.'),
#  ('who', 'PRON'),
#  ('*T*-100', 'NOUN'),
#  ('had', 'VERB'),
#  ('discovered', 'VERB'),
#  ('the', 'DET'),
#  ('crib', 'ADJ'),
#  ('notes', 'NOUN'),
#  ('.', '.'),
#  ('Biscayne', 'NOUN'),
#  ('has', 'VERB'),
#  ("n't", 'ADV'),
#  ('any', 'DET'),
#  ('telephone', 'NOUN'),
#  ('listing', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('operator', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Moreover', 'ADV'),
#  (',', '.'),
#  ('we', 'PRON'),
#  ("'ve", 'VERB'),
#  ('probably', 'ADV'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('most', 'ADJ'),
#  ('aggressive', 'ADJ'),
#  ('firm', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('Street', 'NOUN'),
#  ('in', 'ADP'),
#  ('*', 'X'),
#  ('reducing', 'VERB'),
#  ('costs', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-1', 'X'),
#  ('are', 'VERB'),
#  ('down', 'ADV'),
#  ('around', 'ADP'),
#  ('40', 'NUM'),
#  ('%', 'NOUN'),
#  ('over', 'ADP'),
#  ('the', 'DET'),
#  ('last', 'ADJ'),
#  ('six', 'NUM'),
#  ('months', 'NOUN'),
#  ('.', '.'),
#  ('Then', 'ADV'),
#  (',', '.'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('guests', 'NOUN'),
#  ("'", 'PRT'),
#  ('honor', 'VERB'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('speedway', 'NOUN'),
#  ('hauled', 'NOUN'),
#  ('out', 'PRT'),
#  ('four', 'NUM'),
#  ('drivers', 'NOUN'),
#  (',', '.'),
#  ('crews', 'NOUN'),
#  ('and', 'CONJ'),
#  ('even', 'ADV'),
#  ('the', 'DET'),
#  ('official', 'NOUN'),
#  ('Indianapolis', 'NOUN'),
#  ('500', 'NUM'),
#  ('announcer', 'NOUN'),
#  ('for', 'ADP'),
#  ('a', 'DET'),
#  ('10-lap', 'NOUN'),
#  ('exhibition', 'NOUN'),
#  ('race', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('sale', 'NOUN'),
#  ('comes', 'VERB'),
#  ('in', 'ADP'),
#  ('place', 'NOUN'),
#  ('of', 'ADP'),
#  ('a', 'DET'),
#  ('planned', 'VERB'),
#  ('initial', 'ADJ'),
#  ('public', 'NOUN'),
#  ('offering', 'NOUN'),
#  ('of', 'ADP'),
#  ('Lentjes', 'NOUN'),
#  ('stock', 'NOUN'),
#  ('.', '.'),
#  ('I', 'PRON'),
#  ('say', 'VERB'),
#  ('``', '.'),
#  ('*', 'X'),
#  ('contained', 'VERB'),
#  ('dialogue', 'NOUN'),
#  ("''", '.'),
#  ('because', 'ADP'),
#  ('``', '.'),
#  ('Sidewalk', 'NOUN'),
#  ('Stories', 'NOUN'),
#  ("''", '.'),
#  ('is', 'VERB'),
#  ("n't", 'ADV'),
#  ('really', 'ADV'),
#  ('silent', 'ADJ'),
#  ('at', 'ADP'),
#  ('all', 'DET'),
#  ('.', '.'),
#  ('It', 'PRON'),
#  ("'s", 'VERB'),
#  ('probably', 'ADV'),
#  ('worth', 'ADJ'),
#  ('*', 'X'),
#  ('paying', 'VERB'),
#  ('a', 'DET'),
#  ('premium', 'NOUN'),
#  ('for', 'ADP'),
#  ('funds', 'NOUN'),
#  ('that', 'ADP'),
#  ('*T*-42', 'X'),
#  ('invest', 'VERB'),
#  ('in', 'ADP'),
#  ('markets', 'NOUN'),
#  ('that', 'ADP'),
#  ('*T*-43', 'X'),
#  ('are', 'VERB'),
#  ('partially', 'ADV'),
#  ('closed', 'VERB'),
#  ('to', 'PRT'),
#  ('foreign', 'ADJ'),
#  ('investors', 'NOUN'),
#  (',', '.'),
#  ('such', 'ADJ'),
#  ('as', 'ADP'),
#  ('South', 'NOUN'),
#  ('Korea', 'NOUN'),
#  (',', '.'),
#  ('some', 'DET'),
#  ('specialists', 'NOUN'),
#  ('say', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('California', 'NOUN'),
#  ('Supreme', 'NOUN'),
#  ('Court', 'NOUN'),
#  ('last', 'ADJ'),
#  ('year', 'NOUN'),
#  ('reversed', 'NOUN'),
#  ('direction', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('make', 'VERB'),
#  ('it', 'PRON'),
#  ('*EXP*-2', 'X'),
#  ('much', 'ADV'),
#  ('harder', 'ADJ'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('win', 'VERB'),
#  ('DES', 'NOUN'),
#  ('cases', 'NOUN'),
#  ('because', 'ADP'),
#  ('the', 'DET'),
#  ('justices', 'NOUN'),
#  ('saw', 'VERB'),
#  ('how', 'ADV'),
#  ('all', 'DET'),
#  ('the', 'DET'),
#  ('pharmaceutical', 'ADJ'),
#  ('litigation', 'NOUN'),
#  ('has', 'VERB'),
#  ('chilled', 'NOUN'),
#  ('the', 'DET'),
#  ('introduction', 'NOUN'),
#  ('of', 'ADP'),
#  ('new', 'ADJ'),
#  ('drugs', 'NOUN'),
#  ('*T*-3', 'X'),
#  ('.', '.'),
#  ('A', 'DET'),
#  ('$', '.'),
#  ('114', 'NOUN'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('issue', 'NOUN'),
#  ('of', 'ADP'),
#  ('health', 'NOUN'),
#  ('facility', 'NOUN'),
#  ('revenue', 'NOUN'),
#  ('bonds', 'NOUN'),
#  ('from', 'ADP'),
#  ('the', 'DET'),
#  ('California', 'NOUN'),
#  ('Health', 'NOUN'),
#  ('Facilities', 'NOUN'),
#  ('Financing', 'NOUN'),
#  ('Authority', 'NOUN'),
#  ('was', 'VERB'),
#  ('temporarily', 'ADV'),
#  ('withdrawn', 'VERB'),
#  ('*-1', 'X'),
#  ('after', 'ADP'),
#  ('*-1', 'X'),
#  ('being', 'VERB'),
#  ('tentatively', 'ADV'),
#  ('priced', 'VERB'),
#  ('*-2', 'X'),
#  ('by', 'ADP'),
#  ('a', 'DET'),
#  ('First', 'NOUN'),
#  ('Boston', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('group', 'NOUN'),
#  ('.', '.'),
#  ('There', 'DET'),
#  ("'s", 'VERB'),
#  ('never', 'ADV'),
#  ('been', 'VERB'),
#  ('an', 'DET'),
#  ('exception', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('Gerald', 'NOUN'),
#  ('W.', 'NOUN'),
#  ('Perritt', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('Chicago', 'NOUN'),
#  ('investment', 'NOUN'),
#  ('adviser', 'NOUN'),
#  ('and', 'CONJ'),
#  ('money', 'NOUN'),
#  ('manager', 'NOUN'),
#  (',', '.'),
#  ('based', 'VERB'),
#  ('on', 'ADP'),
#  ('a', 'DET'),
#  ('review', 'NOUN'),
#  ('of', 'ADP'),
#  ('six', 'NUM'),
#  ('decades', 'NOUN'),
#  ('of', 'ADP'),
#  ('stock-market', 'NOUN'),
#  ('data', 'NOUN'),
#  ('.', '.'),
#  ('A', 'DET'),
#  ('look', 'NOUN'),
#  ('at', 'ADP'),
#  ('a', 'DET'),
#  ('Thursday', 'NOUN'),
#  ('night', 'NOUN'),
#  ('practice', 'NOUN'),
#  ('at', 'ADP'),
#  ('St.', 'NOUN'),
#  ('Mary', 'NOUN'),
#  ('Abbot', 'NOUN'),
#  ('church', 'NOUN'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('Kensington', 'NOUN'),
#  ('district', 'NOUN'),
#  ('of', 'ADP'),
#  ('London', 'NOUN'),
#  ('gives', 'VERB'),
#  ('an', 'DET'),
#  ('idea', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('work', 'NOUN'),
#  ('involved', 'VERB'),
#  ('*', 'X'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('I', 'PRON'),
#  ('--', '.'),
#  ('I', 'PRON'),
#  ('like', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('think', 'VERB'),
#  ('of', 'ADP'),
#  ('it', 'PRON'),
#  ('in', 'ADP'),
#  ('terms', 'NOUN'),
#  ('of', 'ADP'),
#  ('we', 'PRON'),
#  (',', '.'),
#  ('all', 'DET'),
#  ...]

# %%
incorrect_tagged_cases = [(j) for i, j in enumerate(zip(validation_Viterbi1, validation_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [(('*-134', 'NOUN'), ('*-134', 'X')),
#  (('*T*-218', 'NOUN'), ('*T*-218', 'X')),
#  (('reports', 'NOUN'), ('reports', 'VERB')),
#  (('floral', 'NOUN'), ('floral', 'ADJ')),
#  (('disapprove', 'NOUN'), ('disapprove', 'VERB')),
#  (('no', 'DET'), ('no', 'ADV')),
#  (('minimal', 'NOUN'), ('minimal', 'ADJ')),
#  (('7.2', 'NOUN'), ('7.2', 'NUM')),
#  (('Some', 'DET'), ('Some', 'ADV')),
#  (('test', 'NOUN'), ('test', 'VERB')),
#  (('Most', 'ADJ'), ('Most', 'ADV')),
#  (('manufacturing', 'NOUN'), ('manufacturing', 'VERB')),
#  (('counts', 'NOUN'), ('counts', 'VERB')),
#  (('counts', 'NOUN'), ('counts', 'VERB')),
#  (('first-time', 'NOUN'), ('first-time', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-99', 'NOUN'), ('*T*-99', 'X')),
#  (('expunged', 'NOUN'), ('expunged', 'VERB')),
#  (('which', 'DET'), ('which', 'ADP')),
#  (('earlier', 'ADV'), ('earlier', 'ADJ')),
#  (('agreed', 'VERB'), ('agreed', 'NOUN')),
#  (('supply', 'NOUN'), ('supply', 'VERB')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('sank', 'NOUN'), ('sank', 'VERB')),
#  (('alleviate', 'NOUN'), ('alleviate', 'VERB')),
#  (('back', 'ADV'), ('back', 'PRT')),
#  (('notes', 'NOUN'), ('notes', 'VERB')),
#  (('cents-a-unit', 'NOUN'), ('cents-a-unit', 'ADJ')),
#  (('liquidated', 'NOUN'), ('liquidated', 'VERB')),
#  (('bolster', 'NOUN'), ('bolster', 'VERB')),
#  (('18-a-share', 'NOUN'), ('18-a-share', 'ADJ')),
#  (('offer', 'VERB'), ('offer', 'NOUN')),
#  (('inching', 'NOUN'), ('inching', 'VERB')),
#  (('labeling', 'NOUN'), ('labeling', 'VERB')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('operational', 'NOUN'), ('operational', 'ADJ')),
#  (('*T*-100', 'NOUN'), ('*T*-100', 'X')),
#  (('crib', 'ADJ'), ('crib', 'NOUN')),
#  (('most', 'ADJ'), ('most', 'ADV')),
#  (('honor', 'VERB'), ('honor', 'NOUN')),
#  (('hauled', 'NOUN'), ('hauled', 'VERB')),
#  (('official', 'NOUN'), ('official', 'ADJ')),
#  (('10-lap', 'NOUN'), ('10-lap', 'ADJ')),
#  (('public', 'NOUN'), ('public', 'ADJ')),
#  (('worth', 'ADJ'), ('worth', 'ADP')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('reversed', 'NOUN'), ('reversed', 'VERB')),
#  (('chilled', 'NOUN'), ('chilled', 'VERB')),
#  (('114', 'NOUN'), ('114', 'NUM')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-186', 'NOUN'), ('*T*-186', 'X')),
#  (('together', 'PRT'), ('together', 'ADV')),
#  (('total', 'ADJ'), ('total', 'VERB')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('280', 'NOUN'), ('280', 'NUM')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('broke', 'NOUN'), ('broke', 'VERB')),
#  (('traced', 'NOUN'), ('traced', 'VERB')),
#  (('2163.2', 'NOUN'), ('2163.2', 'NUM')),
#  (('half-hour', 'ADJ'), ('half-hour', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('screened', 'NOUN'), ('screened', 'VERB')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('missed', 'NOUN'), ('missed', 'VERB')),
#  (('uptick', 'VERB'), ('uptick', 'NOUN')),
#  (('compressed', 'NOUN'), ('compressed', 'VERB')),
#  (('4.9', 'NOUN'), ('4.9', 'NUM')),
#  (('spoke', 'NOUN'), ('spoke', 'VERB')),
#  (('near', 'ADP'), ('near', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-239', 'NOUN'), ('*T*-239', 'X')),
#  (('afflicted', 'NOUN'), ('afflicted', 'VERB')),
#  (('Sino-U.S.', 'ADJ'), ('Sino-U.S.', 'NOUN')),
#  (('sport-utility', 'NOUN'), ('sport-utility', 'ADJ')),
#  (('old-style', 'NOUN'), ('old-style', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('juggle', 'NOUN'), ('juggle', 'VERB')),
#  (('so', 'ADV'), ('so', 'ADP')),
#  (('mirror', 'NOUN'), ('mirror', 'VERB')),
#  (('book', 'NOUN'), ('book', 'VERB')),
#  (('stocks', 'NOUN'), ('stocks', 'ADV')),
#  (('up', 'PRT'), ('up', 'ADP')),
#  (('valuable', 'NOUN'), ('valuable', 'ADJ')),
#  (('works', 'NOUN'), ('works', 'VERB')),
#  (('unitary', 'NOUN'), ('unitary', 'ADJ')),
#  (('executive', 'ADJ'), ('executive', 'NOUN')),
#  (('plan', 'NOUN'), ('plan', 'VERB')),
#  (('fetal-tissue', 'ADJ'), ('fetal-tissue', 'NOUN')),
#  (('nondurable', 'NOUN'), ('nondurable', 'ADJ')),
#  (('last', 'ADJ'), ('last', 'VERB')),
#  (('109.73', 'NOUN'), ('109.73', 'NUM')),
#  (('after', 'ADP'), ('after', 'ADV')),
#  (('before', 'ADP'), ('before', 'ADV')),
#  (('play', 'VERB'), ('play', 'NOUN')),
#  (('unstinting', 'NOUN'), ('unstinting', 'ADJ')),
#  (('repay', 'NOUN'), ('repay', 'VERB')),
#  (('vitriolic', 'NOUN'), ('vitriolic', 'ADJ')),
#  (('mollified', 'NOUN'), ('mollified', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('minor', 'NOUN'), ('minor', 'ADJ')),
#  (('permissible', 'NOUN'), ('permissible', 'ADJ')),
#  (('0.50', 'NOUN'), ('0.50', 'NUM')),
#  (('14.00', 'NOUN'), ('14.00', 'NUM')),
#  (('near-limit', 'NOUN'), ('near-limit', 'ADJ')),
#  (('gain', 'VERB'), ('gain', 'NOUN')),
#  (('flirted', 'NOUN'), ('flirted', 'VERB')),
#  (('*T*-193', 'NOUN'), ('*T*-193', 'X')),
#  (('devoted', 'NOUN'), ('devoted', 'VERB')),
#  (('subject', 'ADJ'), ('subject', 'NOUN')),
#  (('Similar', 'NOUN'), ('Similar', 'ADJ')),
#  (('hamstrung', 'NOUN'), ('hamstrung', 'VERB')),
#  (('English', 'NOUN'), ('English', 'ADJ')),
#  (('finds', 'NOUN'), ('finds', 'VERB')),
#  (('mathematical', 'NOUN'), ('mathematical', 'ADJ')),
#  (('cash-rich', 'NOUN'), ('cash-rich', 'ADJ')),
#  (('lead', 'VERB'), ('lead', 'NOUN')),
#  (('yet', 'ADV'), ('yet', 'CONJ')),
#  (('close', 'VERB'), ('close', 'ADV')),
#  (('force', 'NOUN'), ('force', 'VERB')),
#  (('wrenching', 'NOUN'), ('wrenching', 'ADJ')),
#  (('state-supervised', 'NOUN'), ('state-supervised', 'ADJ')),
#  (('*T*-86', 'NOUN'), ('*T*-86', 'X')),
#  (('leading', 'VERB'), ('leading', 'ADJ')),
#  (('no', 'DET'), ('no', 'ADV')),
#  (('plus', 'CONJ'), ('plus', 'NOUN')),
#  (('view', 'VERB'), ('view', 'NOUN')),
#  (('calls', 'VERB'), ('calls', 'NOUN')),
#  (('sentencing', 'NOUN'), ('sentencing', 'VERB')),
#  (('18-year-old', 'NOUN'), ('18-year-old', 'ADJ')),
#  (('homosexual', 'NOUN'), ('homosexual', 'ADJ')),
#  (('85.7', 'NOUN'), ('85.7', 'NUM')),
#  (('93.3', 'NOUN'), ('93.3', 'NUM')),
#  (('earlier', 'ADV'), ('earlier', 'ADJ')),
#  (('rarely', 'NOUN'), ('rarely', 'ADV')),
#  (('acted', 'NOUN'), ('acted', 'VERB')),
#  (('notes', 'NOUN'), ('notes', 'VERB')),
#  (('*-86', 'NOUN'), ('*-86', 'X')),
#  (('stake', 'NOUN'), ('stake', 'VERB')),
#  (('claims', 'VERB'), ('claims', 'NOUN')),
#  (('before', 'ADP'), ('before', 'ADV')),
#  (('twinned', 'NOUN'), ('twinned', 'VERB')),
#  (('complete', 'VERB'), ('complete', 'ADJ')),
#  (('upstream', 'NOUN'), ('upstream', 'ADV')),
#  (('rings', 'NOUN'), ('rings', 'VERB')),
#  (('Great', 'NOUN'), ('Great', 'ADJ')),
#  (('better', 'ADV'), ('better', 'ADJ')),
#  (('report', 'VERB'), ('report', 'NOUN')),
#  (('arrive', 'NOUN'), ('arrive', 'VERB')),
#  (('firmed', 'NOUN'), ('firmed', 'VERB')),
#  (('faltered', 'NOUN'), ('faltered', 'VERB')),
#  (('Proper', 'NOUN'), ('Proper', 'ADJ')),
#  (('English', 'NOUN'), ('English', 'ADJ')),
#  (('highest-pitched', 'NOUN'), ('highest-pitched', 'ADJ')),
#  (('descending', 'NOUN'), ('descending', 'VERB')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('match', 'VERB'), ('match', 'NOUN')),
#  (('high-quality', 'NOUN'), ('high-quality', 'ADJ')),
#  (('flows', 'NOUN'), ('flows', 'VERB')),
#  (('deteriorating', 'NOUN'), ('deteriorating', 'VERB')),
#  (('most', 'ADV'), ('most', 'ADJ')),
#  (('building', 'NOUN'), ('building', 'VERB')),
#  (('erect', 'NOUN'), ('erect', 'VERB')),
#  (('if', 'ADP'), ('if', 'ADJ')),
#  (('enough', 'ADV'), ('enough', 'ADJ')),
#  (('harvested', 'NOUN'), ('harvested', 'VERB')),
#  (('loading', 'NOUN'), ('loading', 'VERB')),
#  (('rule', 'NOUN'), ('rule', 'VERB')),
#  (('Earlier', 'ADV'), ('Earlier', 'ADJ')),
#  (('defuse', 'NOUN'), ('defuse', 'VERB')),
#  (('head', 'NOUN'), ('head', 'VERB')),
#  (('judged', 'NOUN'), ('judged', 'VERB')),
#  (('bygone', 'NOUN'), ('bygone', 'ADJ')),
#  (('ultimately', 'NOUN'), ('ultimately', 'ADV')),
#  (('regenerate', 'NOUN'), ('regenerate', 'VERB')),
#  (('damaged', 'VERB'), ('damaged', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-114', 'NOUN'), ('*T*-114', 'X')),
#  (('cause', 'NOUN'), ('cause', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-115', 'NOUN'), ('*T*-115', 'X')),
#  (('cause', 'NOUN'), ('cause', 'VERB')),
#  (('cause', 'VERB'), ('cause', 'NOUN')),
#  (('offer', 'NOUN'), ('offer', 'VERB')),
#  (('cost-sharing', 'NOUN'), ('cost-sharing', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('subsidize', 'NOUN'), ('subsidize', 'VERB')),
#  (('clean-up', 'NOUN'), ('clean-up', 'ADJ')),
#  (('coal-fired', 'NOUN'), ('coal-fired', 'ADJ')),
#  (('sparing', 'NOUN'), ('sparing', 'VERB')),
#  (('exorbitant', 'NOUN'), ('exorbitant', 'ADJ')),
#  (('2.46', 'NOUN'), ('2.46', 'NUM')),
#  (('2.42', 'NOUN'), ('2.42', 'NUM')),
#  (('British', 'ADJ'), ('British', 'NOUN')),
#  (('perceives', 'NOUN'), ('perceives', 'VERB')),
#  (('*T*-183', 'NOUN'), ('*T*-183', 'X')),
#  (('Having', 'NOUN'), ('Having', 'VERB')),
#  (('supportive', 'NOUN'), ('supportive', 'ADJ')),
#  (('multilevel', 'NOUN'), ('multilevel', 'ADJ')),
#  (('CLEARS', 'NOUN'), ('CLEARS', 'VERB')),
#  (('homosexual', 'NOUN'), ('homosexual', 'ADJ')),
#  (('export', 'NOUN'), ('export', 'VERB')),
#  (('1990-91', 'NOUN'), ('1990-91', 'NUM')),
#  (('so', 'ADV'), ('so', 'ADP')),
#  (('contesting', 'NOUN'), ('contesting', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-119', 'NOUN'), ('*T*-119', 'X')),
#  (('expires', 'NOUN'), ('expires', 'VERB')),
#  (('next', 'ADP'), ('next', 'ADJ')),
#  (('1920s', 'NOUN'), ('1920s', 'NUM')),
#  (("'30s", 'NOUN'), ("'30s", 'NUM')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('semicircular', 'NOUN'), ('semicircular', 'ADJ')),
#  (('middle', 'ADJ'), ('middle', 'NOUN')),
#  (('shallow', 'NOUN'), ('shallow', 'ADJ')),
#  (('up', 'ADV'), ('up', 'PRT')),
#  (('adapting', 'NOUN'), ('adapting', 'VERB')),
#  (('unethical', 'NOUN'), ('unethical', 'ADJ')),
#  (('higher-salaried', 'NOUN'), ('higher-salaried', 'ADJ')),
#  (('up', 'ADV'), ('up', 'PRT')),
#  (('American-style', 'NOUN'), ('American-style', 'ADJ')),
#  (('most', 'ADJ'), ('most', 'ADV')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-253', 'NOUN'), ('*T*-253', 'X')),
#  (('exploit', 'NOUN'), ('exploit', 'VERB')),
#  (('brief', 'VERB'), ('brief', 'ADJ')),
#  (('focus', 'VERB'), ('focus', 'NOUN')),
#  (('face', 'VERB'), ('face', 'NOUN')),
#  (('692', 'NOUN'), ('692', 'NUM')),
#  (('960', 'NOUN'), ('960', 'NUM')),
#  (('momentary', 'NOUN'), ('momentary', 'ADJ')),
#  (('*T*-112', 'NOUN'), ('*T*-112', 'X')),
#  (('acting', 'NOUN'), ('acting', 'ADJ')),
#  (('*-158', 'NOUN'), ('*-158', 'X')),
#  (('security-type', 'NOUN'), ('security-type', 'ADJ')),
#  (('so', 'ADV'), ('so', 'ADP')),
#  (('anti-takeover', 'NOUN'), ('anti-takeover', 'ADJ')),
#  (('*T*-234', 'NOUN'), ('*T*-234', 'X')),
#  (('next', 'ADP'), ('next', 'ADJ')),
#  (('even', 'ADV'), ('even', 'ADJ')),
#  (('7.2', 'NOUN'), ('7.2', 'NUM')),
#  (('risk-free', 'NOUN'), ('risk-free', 'ADJ')),
#  (('outdistanced', 'NOUN'), ('outdistanced', 'VERB')),
#  (('short', 'ADJ'), ('short', 'ADV')),
#  (('carefree', 'NOUN'), ('carefree', 'ADJ')),
#  (('name', 'NOUN'), ('name', 'VERB')),
#  (('enormously', 'NOUN'), ('enormously', 'ADV')),
#  (('frustrating', 'NOUN'), ('frustrating', 'VERB')),
#  (('raring', 'NOUN'), ('raring', 'ADJ')),
#  (('invent', 'NOUN'), ('invent', 'VERB')),
#  (('funding', 'NOUN'), ('funding', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('visited', 'NOUN'), ('visited', 'VERB')),
#  (('*-149', 'NOUN'), ('*-149', 'X')),
#  (('falsify', 'NOUN'), ('falsify', 'VERB')),
#  (('ultimately', 'NOUN'), ('ultimately', 'ADV')),
#  (('liquidated', 'NOUN'), ('liquidated', 'VERB')),
#  (('distributed', 'NOUN'), ('distributed', 'VERB')),
#  (('tell', 'NOUN'), ('tell', 'VERB')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (("'", 'PRT'), ("'", '.')),
#  (('unfettered', 'NOUN'), ('unfettered', 'ADJ')),
#  (('limit', 'NOUN'), ('limit', 'VERB')),
#  (('lately', 'NOUN'), ('lately', 'ADV')),
#  (('touted', 'NOUN'), ('touted', 'VERB')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('impart', 'NOUN'), ('impart', 'VERB')),
#  (('senior', 'ADJ'), ('senior', 'NOUN')),
#  (('net', 'NOUN'), ('net', 'ADJ')),
#  (('35.2', 'NOUN'), ('35.2', 'NUM')),
#  (('total', 'ADJ'), ('total', 'NOUN')),
#  (('25.6', 'NOUN'), ('25.6', 'NUM')),
#  (('pre-1933', 'NOUN'), ('pre-1933', 'ADJ')),
#  (('key', 'ADJ'), ('key', 'NOUN')),
#  (('satisfying', 'NOUN'), ('satisfying', 'VERB')),
#  (('Standing', 'NOUN'), ('Standing', 'VERB')),
#  (('shaded', 'NOUN'), ('shaded', 'ADJ')),
#  (('educated', 'NOUN'), ('educated', 'VERB')),
#  (('brightest', 'NOUN'), ('brightest', 'ADJ')),
#  (('winning', 'VERB'), ('winning', 'ADJ')),
#  (('26.2', 'NOUN'), ('26.2', 'NUM')),
#  (('automotive-lighting', 'NOUN'), ('automotive-lighting', 'ADJ')),
#  (('leapt', 'NOUN'), ('leapt', 'VERB')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('slow', 'VERB'), ('slow', 'ADJ')),
#  (('computerize', 'NOUN'), ('computerize', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-199', 'NOUN'), ('*T*-199', 'X')),
#  (('Little', 'NOUN'), ('Little', 'ADV')),
#  (('little', 'ADJ'), ('little', 'ADV')),
#  (('Abrupt', 'NOUN'), ('Abrupt', 'ADJ')),
#  (('unheard', 'NOUN'), ('unheard', 'ADJ')),
#  (('879', 'NOUN'), ('879', 'NUM')),
#  (('13.90', 'NOUN'), ('13.90', 'NUM')),
#  (('New', 'NOUN'), ('New', 'ADJ')),
#  (('York-based', 'NOUN'), ('York-based', 'ADJ')),
#  (('guarantee', 'VERB'), ('guarantee', 'NOUN')),
#  (('future', 'ADJ'), ('future', 'NOUN')),
#  (('3,600', 'NOUN'), ('3,600', 'NUM')),
#  (('Wa', 'NOUN'), ('Wa', '.')),
#  (('339', 'NOUN'), ('339', 'NUM')),
#  (('buying', 'VERB'), ('buying', 'NOUN')),
#  (('incentive-backed', 'NOUN'), ('incentive-backed', 'ADJ')),
#  (('untrue', 'NOUN'), ('untrue', 'ADJ')),
#  (('quoting', 'NOUN'), ('quoting', 'VERB')),
#  (('emphasized', 'NOUN'), ('emphasized', 'VERB')),
#  (('1998', 'NOUN'), ('1998', 'NUM')),
#  (('95.09', 'NOUN'), ('95.09', 'NUM')),
#  (('5.435', 'NOUN'), ('5.435', 'NUM')),
#  (('measures', 'NOUN'), ('measures', 'VERB')),
#  (('exchange', 'NOUN'), ('exchange', 'VERB')),
#  (('preferred', 'ADJ'), ('preferred', 'VERB')),
#  (('own', 'ADJ'), ('own', 'VERB')),
#  (('net', 'ADJ'), ('net', 'NOUN')),
#  (('734.9', 'NOUN'), ('734.9', 'NUM')),
#  (('down', 'ADV'), ('down', 'ADP')),
#  (('811.9', 'NOUN'), ('811.9', 'NUM')),
#  (('3.04', 'NOUN'), ('3.04', 'NUM')),
#  (('1996', 'NOUN'), ('1996', 'NUM')),
#  (('Renaissance-style', 'NOUN'), ('Renaissance-style', 'ADJ')),
#  (('relieved', 'NOUN'), ('relieved', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-153', 'NOUN'), ('*T*-153', 'X')),
#  (('financing', 'NOUN'), ('financing', 'VERB')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('support', 'VERB'), ('support', 'NOUN')),
#  (('hard', 'ADJ'), ('hard', 'ADV')),
#  (('more', 'ADJ'), ('more', 'ADV'))]

# %%
pd.Series(np.array([i[1][1] for i in incorrect_tagged_cases])).value_counts()
# Out:
# VERB    99
# ADJ     87
# NUM     32
# NOUN    32
# ADV     29
# X       20
# DET     18
# ADP      8
# PRT      3
# .        2
# CONJ     1
# dtype: int64
