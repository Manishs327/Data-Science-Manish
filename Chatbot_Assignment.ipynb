# %%
# !pip install rasa-x --extra-index-url https://pypi.rasa.com/simple
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.rasa.com/simple
# Collecting rasa-x
#   Downloading https://pypi.rasa.com/api/package/rasa-x/rasa_x-0.34.0-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 40.0MB/s
# Collecting ujson<2.0,>=1.35
#   Downloading https://files.pythonhosted.org/packages/16/c4/79f3409bc710559015464e5f49b9879430d8f87498ecdc335899732e5377/ujson-1.35.tar.gz (192kB)
#      |████████████████████████████████| 194kB 13.7MB/s
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from rasa-x) (51.0.0)
# Collecting cryptography<3.0,>=2.7
#   Downloading https://files.pythonhosted.org/packages/3c/04/686efee2dcdd25aecf357992e7d9362f443eb182ecd623f882bc9f7a6bba/cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 36.7MB/s
# Collecting sanic<21.0.0,>=19.12.2
#   Downloading https://files.pythonhosted.org/packages/f0/9d/30d32d1705988494426932caa4ee7f35fc7f42f56c20ca19ee5cdac7a2b2/sanic-20.12.1-py3-none-any.whl (79kB)
#      |████████████████████████████████| 81kB 9.1MB/s
# Collecting attrs<20.0,>=19.3
#   Downloading https://files.pythonhosted.org/packages/a2/db/4313ab3be961f7a763066401fb77f7748373b6094076ae2bda2806988af6/attrs-19.3.0-py2.py3-none-any.whl
# Collecting isodate<0.7,>=0.6
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 7.2MB/s
# Collecting pika<2.0.0,>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/a1/ae/8bedf0e9f1c0c5d046db3a7428a4227fe36ec1b8e25607f3c38ac9bf513c/pika-1.1.0-py2.py3-none-any.whl (148kB)
#      |████████████████████████████████| 153kB 56.6MB/s
# Collecting ruamel.yaml<0.17,>=0.16
#   Downloading https://files.pythonhosted.org/packages/7e/39/186f14f3836ac5d2a6a042c8de69988770e8b9abb537610edc429e4914aa/ruamel.yaml-0.16.12-py2.py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 56.2MB/s
# Requirement already satisfied: requests<3.0,>=2.23 in /usr/local/lib/python3.6/dist-packages (from rasa-x) (2.23.0)
# Collecting kafka-python<2.0,>=1.4
#   Downloading https://files.pythonhosted.org/packages/49/c9/9863483a1353700ba87821b4f39085eb18fd1bcbb1e954c697177d67f03f/kafka_python-1.4.7-py2.py3-none-any.whl (266kB)
#      |████████████████████████████████| 266kB 47.0MB/s
# Collecting questionary<1.6.0,>=1.5.1
#   Downloading https://files.pythonhosted.org/packages/05/7d/61b7d0da15bb50e7239c870771320026447b7e2d9490ee96f49dddd3ef0d/questionary-1.5.2-py3-none-any.whl
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in /usr/local/lib/python3.6/dist-packages (from rasa-x) (2.8.1)
# Collecting aiohttp<4.0,>=3.6
#   Downloading https://files.pythonhosted.org/packages/ad/e6/d4b6235d776c9b33f853e603efede5aac5a34f71ca9d3877adb30492eb4e/aiohttp-3.7.3-cp36-cp36m-manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 52.6MB/s
# Collecting rasa<3.0.0,>=2.0.2
#   Downloading https://files.pythonhosted.org/packages/9a/2f/12ea664440cc7eb64fe45af2a156a29d4786018717828f93d066e423c2b6/rasa-2.2.3-py3-none-any.whl (688kB)
#      |████████████████████████████████| 696kB 51.0MB/s
# Collecting alembic<2.0.0,>=1.0.10
#   Downloading https://files.pythonhosted.org/packages/12/aa/c261dfd7f4ba6ce4701846a2689a46e2a172e012171de4378fc2926e3bf0/alembic-1.4.3-py2.py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 53.5MB/s
# Collecting psycopg2-binary<3.0.0,>=2.8.2
#   Downloading https://files.pythonhosted.org/packages/f2/1b/720b36697158113ca1b2221a8e96a470088ccf3770d182214689d1a96a07/psycopg2_binary-2.8.6-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 49.6MB/s
# Requirement already satisfied: SQLAlchemy<2.0.0,>=1.3.19 in /usr/local/lib/python3.6/dist-packages (from rasa-x) (1.3.20)
# Collecting sanic-cors<0.11.0,>=0.10.0b1
#   Downloading https://files.pythonhosted.org/packages/2d/33/5e1776669aa62dd9c65e3513425077915acb1758d6b19f08f830f27ce9a8/Sanic_Cors-0.10.0.post3-py2.py3-none-any.whl
# Collecting GitPython<4.0.0,>=3.1.3
#   Downloading https://files.pythonhosted.org/packages/d7/cb/ec98155c501b68dcb11314c7992cd3df6dce193fd763084338a117967d53/GitPython-3.1.12-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 48.1MB/s
# Collecting sanic-jwt<1.5.0,>=1.3.2
#   Downloading https://files.pythonhosted.org/packages/ed/ca/61b5c31074890ae62cfd00edc940450a9575d46371a92974301595b18edf/sanic-jwt-1.4.1.tar.gz
# Collecting jsonschema<4.0,>=3.2
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 9.0MB/s
# Collecting apscheduler<4.0,>=3.6
#   Downloading https://files.pythonhosted.org/packages/f3/34/9ef20ed473c4fd2c3df54ef77a27ae3fc7500b16b192add4720cab8b2c09/APScheduler-3.6.3-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 9.3MB/s
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography<3.0,>=2.7->rasa-x) (1.14.4)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from cryptography<3.0,>=2.7->rasa-x) (1.15.0)
# Collecting httptools>=0.0.10
#   Downloading https://files.pythonhosted.org/packages/b1/a6/dc1e7e8f4049ab70d52c9690ec10652e268ab2542853033cc1d539594102/httptools-0.1.1-cp36-cp36m-manylinux1_x86_64.whl (216kB)
#      |████████████████████████████████| 225kB 51.4MB/s
# Collecting aiofiles>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/ba/21/df5eae4b6db2eb00d58428dd7f793ecbf99942fcafcea141cbf108fa72f4/aiofiles-0.6.0-py3-none-any.whl
# Collecting httpx==0.15.4
#   Downloading https://files.pythonhosted.org/packages/b3/01/0b3a83352d75e3e57134abf5bef8fa3c64152e6107b5d57d510ad8d49a2a/httpx-0.15.4-py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 10.3MB/s
# Collecting websockets<9.0,>=8.1
#   Downloading https://files.pythonhosted.org/packages/bb/d9/856af84843912e2853b1b6e898ac8b802989fcf9ecf8e8445a1da263bf3b/websockets-8.1-cp36-cp36m-manylinux2010_x86_64.whl (78kB)
#      |████████████████████████████████| 81kB 7.8MB/s
# Collecting uvloop>=0.5.3; sys_platform != "win32" and implementation_name == "cpython"
#   Downloading https://files.pythonhosted.org/packages/41/48/586225bbb02d3bdca475b17e4be5ce5b3f09da2d6979f359916c1592a687/uvloop-0.14.0-cp36-cp36m-manylinux2010_x86_64.whl (3.9MB)
#      |████████████████████████████████| 3.9MB 50.0MB/s
# Collecting multidict<6.0,>=5.0
#   Downloading https://files.pythonhosted.org/packages/a1/35/b22524d6b9cacfb4c5eff413a069bbc17c6ea628e54da5c6c989998ced5f/multidict-5.1.0-cp36-cp36m-manylinux2014_x86_64.whl (141kB)
#      |████████████████████████████████| 143kB 54.2MB/s
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading https://files.pythonhosted.org/packages/88/ff/ec25dc01ef04232a9e68ff18492e37dfa01f1f58172e702ad4f38536d41b/ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549kB)
#      |████████████████████████████████| 552kB 49.3MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.23->rasa-x) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.23->rasa-x) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.23->rasa-x) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.23->rasa-x) (3.0.4)
# Collecting prompt-toolkit<4.0,>=2.0
#   Downloading https://files.pythonhosted.org/packages/f7/11/153bde8264af33aacf10da4fa5f464e595a3b61e490bfb9acb2431f552e5/prompt_toolkit-3.0.9-py3-none-any.whl (355kB)
#      |████████████████████████████████| 358kB 54.7MB/s
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.6/dist-packages (from aiohttp<4.0,>=3.6->rasa-x) (3.7.4.3)
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/da/08/52b26b44bce7b818b410aee37c5e424c9ea420c557bca97dc2adac29b151/yarl-1.6.3-cp36-cp36m-manylinux2014_x86_64.whl (293kB)
#      |████████████████████████████████| 296kB 27.0MB/s
# Collecting idna-ssl>=1.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/46/03/07c4894aae38b0de52b52586b24bf189bb83e4ddabfe2e2c8f2419eec6f4/idna-ssl-1.1.0.tar.gz
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Collecting redis<4.0,>=3.4
#   Downloading https://files.pythonhosted.org/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl (72kB)
#      |████████████████████████████████| 81kB 10.9MB/s
# Collecting tensorflow-estimator<2.4,>=2.3
#   Downloading https://files.pythonhosted.org/packages/e9/ed/5853ec0ae380cba4588eab1524e18ece1583b65f7ae0e97321f5ff9dfd60/tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459kB)
#      |████████████████████████████████| 460kB 45.6MB/s
# Collecting tensorflow-text<2.4,>=2.3; sys_platform != "win32"
#   Downloading https://files.pythonhosted.org/packages/28/b2/2dbd90b93913afd07e6101b8b84327c401c394e60141c1e98590038060b3/tensorflow_text-2.3.0-cp36-cp36m-manylinux1_x86_64.whl (2.6MB)
#      |████████████████████████████████| 2.6MB 46.3MB/s
# Collecting sklearn-crfsuite<0.4,>=0.3
#   Downloading https://files.pythonhosted.org/packages/25/74/5b7befa513482e6dee1f3dd68171a6c9dfc14c0eaa00f885ffeba54fe9b0/sklearn_crfsuite-0.3.6-py2.py3-none-any.whl
# Collecting colorclass<2.3,>=2.2
#   Downloading https://files.pythonhosted.org/packages/37/ea/ae8dbb956939d4392e6a7fdef87fda273854da1128edae016c4104240be8/colorclass-2.2.0.tar.gz
# Collecting rasa-sdk<3.0.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/12/7b/62f62d7a036a21e2b9426337782c2bd789dc81001823ae3ffe2e844b381e/rasa_sdk-2.2.0-py3-none-any.whl (42kB)
#      |████████████████████████████████| 51kB 7.5MB/s
# Collecting slackclient<3.0.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/ed/27/de9ce989d0964518152e1a164b08971c77a173b051a153e50220f1a963d9/slackclient-2.9.3-py2.py3-none-any.whl (96kB)
#      |████████████████████████████████| 102kB 12.0MB/s
# Requirement already satisfied: scipy<2.0.0,>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (1.4.1)
# Collecting regex<2020.10,>=2020.6
#   Downloading https://files.pythonhosted.org/packages/e4/90/0dae9bdebd8f8f8a39f1b80fdef240bec36ff64359f5fc584034ce4633cf/regex-2020.9.27-cp36-cp36m-manylinux2010_x86_64.whl (662kB)
#      |████████████████████████████████| 665kB 46.9MB/s
# Requirement already satisfied: tqdm<4.51,>=4.31 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (4.41.1)
# Collecting python-engineio<3.14,>=3.11
#   Downloading https://files.pythonhosted.org/packages/4a/b0/602e549c6d735eb487f186b35e0b82e61c89459f57d1c24d5c7be6f56d05/python_engineio-3.13.2-py2.py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 820kB/s
# Collecting terminaltables<3.2.0,>=3.1.0
#   Downloading https://files.pythonhosted.org/packages/9b/c4/4a21174f32f8a7e1104798c445dacdc1d4df86f2f26722767034e4de4bff/terminaltables-3.1.0.tar.gz
# Collecting tensorflow_hub<0.10,>=0.9
#   Downloading https://files.pythonhosted.org/packages/ac/83/a7df82744a794107641dad1decaad017d82e25f0e1f761ac9204829eef96/tensorflow_hub-0.9.0-py2.py3-none-any.whl (103kB)
#      |████████████████████████████████| 112kB 48.1MB/s
# Collecting joblib<0.16.0,>=0.15.1
#   Downloading https://files.pythonhosted.org/packages/b8/a6/d1a816b89aa1e9e96bcb298eb1ee1854f21662ebc6d55ffa3d7b3b50122b/joblib-0.15.1-py3-none-any.whl (298kB)
#      |████████████████████████████████| 307kB 60.1MB/s
# Collecting fbmessenger<6.1.0,>=6.0.0
#   Downloading https://files.pythonhosted.org/packages/bd/e9/646684226176782b9e3b7dd5b35d7ecfd1d13cba24ad2e33255079921aab/fbmessenger-6.0.0-py2.py3-none-any.whl
# Collecting pydot<1.5,>=1.4
#   Downloading https://files.pythonhosted.org/packages/33/d1/b1479a770f66d962f545c2101630ce1d5592d90cb4f083d38862e93d16d2/pydot-1.4.1-py2.py3-none-any.whl
# Collecting aio-pika<7.0.0,>=6.7.1
#   Downloading https://files.pythonhosted.org/packages/57/9a/6fc106a9827e4424c4e0172674344086e5c0066c087f58b00c2d072b32af/aio_pika-6.7.1-py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 8.3MB/s
# Collecting sentry-sdk<0.20.0,>=0.17.0
#   Downloading https://files.pythonhosted.org/packages/b1/5c/018bf9a5c24343a664deaea70e61f33f53bb1bd3caf193110f827bfd07e2/sentry_sdk-0.19.5-py2.py3-none-any.whl (128kB)
#      |████████████████████████████████| 133kB 54.4MB/s
# Collecting python-socketio<4.7,>=4.4
#   Downloading https://files.pythonhosted.org/packages/b2/91/d78afbe5861de53cafe9dcc6eb1a802d5495cfbffb79b8385ee7cf15a71c/python_socketio-4.6.1-py2.py3-none-any.whl (51kB)
#      |████████████████████████████████| 61kB 9.4MB/s
# Requirement already satisfied: networkx<2.6,>=2.4 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (2.5)
# Collecting colorhash<1.1.0,>=1.0.2
#   Downloading https://files.pythonhosted.org/packages/ce/73/e867cd41ab0c15b26f89b0382527e525a2bee8f80ef7ac619fbe16f6ece6/colorhash-1.0.3-py3-none-any.whl
# Requirement already satisfied: scikit-learn<0.24,>=0.22 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (0.22.2.post1)
# Collecting webexteamssdk<1.7.0,>=1.1.1
#   Downloading https://files.pythonhosted.org/packages/4d/27/20edad1a463bd709e90ccc6be12cd5ce5db7ebeda98084143902c226adda/webexteamssdk-1.6-py3-none-any.whl (113kB)
#      |████████████████████████████████| 122kB 53.5MB/s
# Requirement already satisfied: matplotlib<3.4,>=3.1 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (3.2.2)
# Collecting jsonpickle<1.5,>=1.3
#   Downloading https://files.pythonhosted.org/packages/ee/d5/1cc282dc23346a43aab461bf2e8c36593aacd34242bee1a13fa750db0cfe/jsonpickle-1.4.2-py2.py3-none-any.whl
# Collecting pymongo[srv,tls]<3.11,>=3.8
#   Downloading https://files.pythonhosted.org/packages/df/a5/84cf94d7718a107d84ac897c39850bbdd509a924b05942cad4768031ac6f/pymongo-3.10.1-cp36-cp36m-manylinux2014_x86_64.whl (460kB)
#      |████████████████████████████████| 460kB 54.6MB/s
# Collecting PyJWT<1.8,>=1.7
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Collecting tensorflow-addons<=0.12,>=0.10
#   Downloading https://files.pythonhosted.org/packages/d6/98/8e97194e774f35a1319668e12571d5fa19f323e0ccae9d9890258aab1fcc/tensorflow_addons-0.12.0-cp36-cp36m-manylinux2010_x86_64.whl (703kB)
#      |████████████████████████████████| 706kB 52.8MB/s
# Collecting tensorflow<2.4,>=2.3
#   Downloading https://files.pythonhosted.org/packages/a8/a6/4c656fb0361871f8013ce5aba2ef2bf5f7dddf1cd7a9dc34c87934662e2c/tensorflow-2.3.2-cp36-cp36m-manylinux2010_x86_64.whl (320.4MB)
#      |████████████████████████████████| 320.4MB 52kB/s
# Collecting mattermostwrapper<2.3,>=2.2
#   Downloading https://files.pythonhosted.org/packages/d7/fd/f1ce046ddaeffa5073f87d7800c27ad2c8e543e924a8418675c64aea6a14/mattermostwrapper-2.2.tar.gz
# Collecting boto3<2.0,>=1.12
#   Downloading https://files.pythonhosted.org/packages/c8/c6/b4d9547a493ac2837f296f4a004dff6e7136cf6750d181769b8a61d63813/boto3-1.16.50.tar.gz (100kB)
#      |████████████████████████████████| 102kB 14.4MB/s
# Collecting pytz<2021.0,>=2019.1
#   Downloading https://files.pythonhosted.org/packages/89/06/2c2d3034b4d6bf22f2a4ae546d16925898658a33b4400cfb7e2c1e2871a3/pytz-2020.5-py2.py3-none-any.whl (510kB)
#      |████████████████████████████████| 512kB 54.1MB/s
# Requirement already satisfied: async_generator<1.11,>=1.10 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (1.10)
# Collecting rocketchat_API<1.10.0,>=0.6.31
#   Downloading https://files.pythonhosted.org/packages/fb/eb/bbedade2a83f04f8dbc9433cc1663e56585ff9be29d10a0fc4eb8bb01faa/rocketchat_API-1.9.1-py3-none-any.whl
# Requirement already satisfied: tensorflow-probability<0.12,>=0.11 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (0.11.0)
# Requirement already satisfied: cloudpickle<1.5,>=1.2 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (1.3.0)
# Requirement already satisfied: absl-py<0.11,>=0.9 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (0.10.0)
# Requirement already satisfied: packaging<21.0,>=20.0 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (20.8)
# Requirement already satisfied: numpy<2.0,>=1.16 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (1.19.4)
# Collecting coloredlogs<15,>=10
#   Downloading https://files.pythonhosted.org/packages/f3/56/c11e7ef34316b22db4e6d1b9de6e54f332243b72ce63eab676f87744d5ad/coloredlogs-14.3-py2.py3-none-any.whl (44kB)
#      |████████████████████████████████| 51kB 7.6MB/s
# Requirement already satisfied: oauth2client==4.1.3 in /usr/local/lib/python3.6/dist-packages (from rasa<3.0.0,>=2.0.2->rasa-x) (4.1.3)
# Collecting pykwalify<1.8.0,>=1.7.0
#   Downloading https://files.pythonhosted.org/packages/36/9f/612de8ca540bd24d604f544248c4c46e9db76f6ea5eb75fb4244da6ebbf0/pykwalify-1.7.0-py2.py3-none-any.whl (40kB)
#      |████████████████████████████████| 40kB 7.4MB/s
# Collecting twilio<6.46,>=6.26
#   Downloading https://files.pythonhosted.org/packages/68/12/1904b22c2d622a4f1eeb3bea84250f07ed2bfc65fff6139bf1ba7111dd21/twilio-6.45.4.tar.gz (457kB)
#      |████████████████████████████████| 460kB 56.9MB/s
# Collecting pyTelegramBotAPI<4.0.0,>=3.7.3
#   Downloading https://files.pythonhosted.org/packages/2b/43/c86538ae1a81308768cd2fc362c02d808cb99274fb502e2dd9f30ade6ce9/pyTelegramBotAPI-3.7.4.tar.gz (78kB)
#      |████████████████████████████████| 81kB 12.3MB/s
# Collecting python-editor>=0.3
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Collecting Mako
#   Downloading https://files.pythonhosted.org/packages/a6/37/0e706200d22172eb8fa17d68a7ae22dec7631a0a92266634fb518a88a5b2/Mako-1.1.3-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 12.4MB/s
# Collecting sanic-plugins-framework>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/ca/f9/8b2dfad92df5fc37fb764c91b8a45754119ad6f3f9d289188d2bd6f6252f/Sanic_Plugins_Framework-0.9.4.post1-py2.py3-none-any.whl
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 11.8MB/s
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema<4.0,>=3.2->rasa-x) (0.17.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from jsonschema<4.0,>=3.2->rasa-x) (3.3.0)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.6/dist-packages (from apscheduler<4.0,>=3.6->rasa-x) (1.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography<3.0,>=2.7->rasa-x) (2.20)
# Collecting sniffio
#   Downloading https://files.pythonhosted.org/packages/52/b0/7b2e028b63d092804b6794595871f936aafa5e9322dcaaad50ebf67445b3/sniffio-1.2.0-py3-none-any.whl
# Collecting httpcore==0.11.*
#   Downloading https://files.pythonhosted.org/packages/d8/e7/f25e08617b4be99d38e4ef6c4d1b744bf065b9c93156ecd691d95897e0e4/httpcore-0.11.1-py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 10.0MB/s
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading https://files.pythonhosted.org/packages/78/be/7b8b99fd74ff5684225f50dd0e865393d2265656ef3b4ba9eaaaffe622b8/rfc3986-1.4.0-py2.py3-none-any.whl
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<4.0,>=2.0->questionary<1.6.0,>=1.5.1->rasa-x) (0.2.5)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite<0.4,>=0.3->rasa<3.0.0,>=2.0.2->rasa-x) (0.8.7)
# Collecting python-crfsuite>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/95/99/869dde6dbf3e0d07a013c8eebfb0a3d30776334e0097f8432b631a9a3a19/python_crfsuite-0.9.7-cp36-cp36m-manylinux1_x86_64.whl (743kB)
#      |████████████████████████████████| 747kB 54.0MB/s
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_hub<0.10,>=0.9->rasa<3.0.0,>=2.0.2->rasa-x) (3.12.4)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.6/dist-packages (from pydot<1.5,>=1.4->rasa<3.0.0,>=2.0.2->rasa-x) (2.4.7)
# Collecting aiormq<4,>=3.2.3
#   Downloading https://files.pythonhosted.org/packages/0b/c4/dc5b9d50c15af2ee187974a5a0c3f20c06cce6559eea4c065d372e846b6a/aiormq-3.3.1-py3-none-any.whl
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx<2.6,>=2.4->rasa<3.0.0,>=2.0.2->rasa-x) (4.4.2)
# Collecting requests-toolbelt
#   Downloading https://files.pythonhosted.org/packages/60/ef/7681134338fc097acef8d9b2f8abe0458e4d87559c689a8c306d0957ece5/requests_toolbelt-0.9.1-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 8.5MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa<3.0.0,>=2.0.2->rasa-x) (0.16.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib<3.4,>=3.1->rasa<3.0.0,>=2.0.2->rasa-x) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib<3.4,>=3.1->rasa<3.0.0,>=2.0.2->rasa-x) (1.3.1)
# Collecting dnspython<2.0.0,>=1.16.0; extra == "srv"
#   Downloading https://files.pythonhosted.org/packages/ec/d3/3aa0e7213ef72b8585747aa0e271a9523e713813b9a20177ebe1e939deb0/dnspython-1.16.0-py2.py3-none-any.whl (188kB)
#      |████████████████████████████████| 194kB 62.1MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons<=0.12,>=0.10->rasa<3.0.0,>=2.0.2->rasa-x) (2.7.1)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (2.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (1.32.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (1.1.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (3.3.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (1.6.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (0.36.2)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (2.4.0)
# Collecting botocore<1.20.0,>=1.19.50
#   Downloading https://files.pythonhosted.org/packages/16/19/113344007b2c1e4401f404f8e809f6151c00b164d78b164e4b688d30fc67/botocore-1.19.50-py2.py3-none-any.whl (7.2MB)
#      |████████████████████████████████| 7.2MB 34.3MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 11.3MB/s
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability<0.12,>=0.11->rasa<3.0.0,>=2.0.2->rasa-x) (0.1.5)
# Collecting humanfriendly>=7.1
#   Downloading https://files.pythonhosted.org/packages/93/66/363d01a81da2108a5cf446daf619779f06d49a0c4426dd02b40734f10e2f/humanfriendly-9.1-py2.py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 13.9MB/s
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client==4.1.3->rasa<3.0.0,>=2.0.2->rasa-x) (4.6)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client==4.1.3->rasa<3.0.0,>=2.0.2->rasa-x) (0.4.8)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client==4.1.3->rasa<3.0.0,>=2.0.2->rasa-x) (0.17.4)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client==4.1.3->rasa<3.0.0,>=2.0.2->rasa-x) (0.2.8)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.6/dist-packages (from pykwalify<1.8.0,>=1.7.0->rasa<3.0.0,>=2.0.2->rasa-x) (0.6.2)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.6/dist-packages (from pykwalify<1.8.0,>=1.7.0->rasa<3.0.0,>=2.0.2->rasa-x) (3.13)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from Mako->alembic<2.0.0,>=1.0.10->rasa-x) (1.1.1)
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->jsonschema<4.0,>=3.2->rasa-x) (3.4.0)
# Collecting contextvars>=2.1; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/96/55b82d9f13763be9d672622e1b8106c85acb83edd7cc2fa5bc67cd9877e9/contextvars-2.4.tar.gz
# Collecting h11<0.10,>=0.8
#   Downloading https://files.pythonhosted.org/packages/5a/fd/3dad730b0f95e78aeeb742f96fa7bbecbdd56a58e405d3da440d5bfb90c6/h11-0.9.0-py2.py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 9.5MB/s
# Collecting pamqp==2.3.0
#   Downloading https://files.pythonhosted.org/packages/eb/56/afa06143361e640c9159d828dadc95fc9195c52c95b4a97d136617b0166d/pamqp-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (0.4.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (3.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (1.7.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (1.17.2)
# Collecting immutables>=0.9
#   Downloading https://files.pythonhosted.org/packages/99/e0/ea6fd4697120327d26773b5a84853f897a68e33d3f9376b00a8ff96e4f63/immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98kB)
#      |████████████████████████████████| 102kB 15.1MB/s
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (4.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa<3.0.0,>=2.0.2->rasa-x) (3.1.0)
# Building wheels for collected packages: ujson, sanic-jwt, idna-ssl, colorclass, terminaltables, mattermostwrapper, boto3, twilio, pyTelegramBotAPI, contextvars
#   Building wheel for ujson (setup.py) ... done
#   Created wheel for ujson: filename=ujson-1.35-cp36-cp36m-linux_x86_64.whl size=68018 sha256=c5c70f33838724ee2baf61c9fc0950521598ac983f1bae90f90310e98d19e585
#   Stored in directory: /root/.cache/pip/wheels/28/77/e4/0311145b9c2e2f01470e744855131f9e34d6919687550f87d1
#   Building wheel for sanic-jwt (setup.py) ... done
#   Created wheel for sanic-jwt: filename=sanic_jwt-1.4.1-cp36-none-any.whl size=21615 sha256=0fa481e935508dc924f7f4609010c9c91a4f390a1e8943216ed81b2cd6cdd0ba
#   Stored in directory: /root/.cache/pip/wheels/4d/f7/9b/a6ff52d9805d0bca73082fb43a2dd46283138d83fd453a62fb
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3163 sha256=e71f5fbdcc5b865e5f23e5def91d7d3a43fb3a3751629c937d67065661352d75
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
#   Building wheel for colorclass (setup.py) ... done
#   Created wheel for colorclass: filename=colorclass-2.2.0-cp36-none-any.whl size=19396 sha256=94ed067bf87be798a444a0ddd38580b50867d33ebf086e2ccad02c4d2e3e481f
#   Stored in directory: /root/.cache/pip/wheels/d1/86/9d/16127127306a92d7fd30267890a5634026c045391979c4c317
#   Building wheel for terminaltables (setup.py) ... done
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-cp36-none-any.whl size=15358 sha256=7677651460889e1a1a4fad59c25360bb0eb015277076ff21c1be5a81c120cc0f
#   Stored in directory: /root/.cache/pip/wheels/30/6b/50/6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
#   Building wheel for mattermostwrapper (setup.py) ... done
#   Created wheel for mattermostwrapper: filename=mattermostwrapper-2.2-cp36-none-any.whl size=2466 sha256=cb6e092a27ef3cfff2d04ef54182f7742df7b92dddb2f129cf873776d1c0d316
#   Stored in directory: /root/.cache/pip/wheels/c5/47/19/47188b3036316651250c4f7df23d59a3b524c82921bfb6daa3
#   Building wheel for boto3 (setup.py) ... done
#   Created wheel for boto3: filename=boto3-1.16.50-py2.py3-none-any.whl size=128710 sha256=22b05ab1fa707a784baf05ddb815486d17391c0c8810e197359d5512d8c60f39
#   Stored in directory: /root/.cache/pip/wheels/4d/7a/70/33e66d82b7829099a8f9a9abbb669195cf10e4a7b25ff2bc2a
#   Building wheel for twilio (setup.py) ... done
#   Created wheel for twilio: filename=twilio-6.45.4-py2.py3-none-any.whl size=1211595 sha256=f25a46efd1f0fa03ba3bd3e19d824fd41597a22e76dcb133ae2b94aa3aa59773
#   Stored in directory: /root/.cache/pip/wheels/1d/61/91/fff62515b077db8f02e731de1f01315e3f31c862a60d6dd014
#   Building wheel for pyTelegramBotAPI (setup.py) ... done
#   Created wheel for pyTelegramBotAPI: filename=pyTelegramBotAPI-3.7.4-cp36-none-any.whl size=57229 sha256=17f603962fd0d9f808b69b1858eca349050f50aac8c21e91c71bbf404b2dd5da
#   Stored in directory: /root/.cache/pip/wheels/9c/7a/b5/bb04c3ea570dc3f6b9609639543b7e37de14c359b958651899
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-cp36-none-any.whl size=7667 sha256=009d4df3c303b6e7c557f4ae4f348ccb9741c699d08b7087ec19dec0355de921
#   Stored in directory: /root/.cache/pip/wheels/a5/7d/68/1ebae2668bda2228686e3c1cf16f2c2384cea6e9334ad5f6de
# Successfully built ujson sanic-jwt idna-ssl colorclass terminaltables mattermostwrapper boto3 twilio pyTelegramBotAPI contextvars
# ERROR: tensorflow 2.3.2 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.4 which is incompatible.
# ERROR: nbclient 0.5.1 has requirement jupyter-client>=6.1.5, but you'll have jupyter-client 5.3.5 which is incompatible.
# ERROR: jupyter-console 5.2.0 has requirement prompt-toolkit<2.0.0,>=1.0.0, but you'll have prompt-toolkit 3.0.9 which is incompatible.
# ERROR: ipython 5.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.4, but you'll have prompt-toolkit 3.0.9 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: convertdate 2.2.0 has requirement pytz<2020,>=2014.10, but you'll have pytz 2020.5 which is incompatible.
# ERROR: botocore 1.19.50 has requirement urllib3<1.27,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# ERROR: rasa 2.2.3 has requirement aiohttp<3.7,>=3.6, but you'll have aiohttp 3.7.3 which is incompatible.
# ERROR: rasa 2.2.3 has requirement multidict<5.0,>=4.6, but you'll have multidict 5.1.0 which is incompatible.
# ERROR: rasa 2.2.3 has requirement prompt-toolkit<3.0,>=2.0, but you'll have prompt-toolkit 3.0.9 which is incompatible.
# Installing collected packages: ujson, cryptography, httptools, aiofiles, immutables, contextvars, sniffio, h11, httpcore, rfc3986, httpx, websockets, uvloop, multidict, sanic, attrs, isodate, pika, ruamel.yaml.clib, ruamel.yaml, kafka-python, prompt-toolkit, questionary, yarl, idna-ssl, async-timeout, aiohttp, redis, tensorflow-estimator, tensorflow, tensorflow-text, python-crfsuite, sklearn-crfsuite, colorclass, humanfriendly, coloredlogs, sanic-plugins-framework, sanic-cors, rasa-sdk, slackclient, regex, python-engineio, terminaltables, tensorflow-hub, joblib, fbmessenger, pydot, pamqp, aiormq, aio-pika, sentry-sdk, python-socketio, colorhash, requests-toolbelt, PyJWT, webexteamssdk, jsonpickle, dnspython, pymongo, tensorflow-addons, pytz, apscheduler, mattermostwrapper, jmespath, botocore, s3transfer, boto3, rocketchat-API, psycopg2-binary, sanic-jwt, jsonschema, pykwalify, twilio, pyTelegramBotAPI, rasa, python-editor, Mako, alembic, smmap, gitdb, GitPython, rasa-x
#   Found existing installation: attrs 20.3.0
#     Uninstalling attrs-20.3.0:
#       Successfully uninstalled attrs-20.3.0
#   Found existing installation: prompt-toolkit 1.0.18
#     Uninstalling prompt-toolkit-1.0.18:
#       Successfully uninstalled prompt-toolkit-1.0.18
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorflow 2.4.0
#     Uninstalling tensorflow-2.4.0:
#       Successfully uninstalled tensorflow-2.4.0
#   Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Found existing installation: tensorflow-hub 0.10.0
#     Uninstalling tensorflow-hub-0.10.0:
#       Successfully uninstalled tensorflow-hub-0.10.0
#   Found existing installation: joblib 1.0.0
#     Uninstalling joblib-1.0.0:
#       Successfully uninstalled joblib-1.0.0
#   Found existing installation: pydot 1.3.0
#     Uninstalling pydot-1.3.0:
#       Successfully uninstalled pydot-1.3.0
#   Found existing installation: pymongo 3.11.2
#     Uninstalling pymongo-3.11.2:
#       Successfully uninstalled pymongo-3.11.2
#   Found existing installation: tensorflow-addons 0.8.3
#     Uninstalling tensorflow-addons-0.8.3:
#       Successfully uninstalled tensorflow-addons-0.8.3
#   Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Found existing installation: jsonschema 2.6.0
#     Uninstalling jsonschema-2.6.0:
#       Successfully uninstalled jsonschema-2.6.0
# Successfully installed GitPython-3.1.12 Mako-1.1.3 PyJWT-1.7.1 aio-pika-6.7.1 aiofiles-0.6.0 aiohttp-3.7.3 aiormq-3.3.1 alembic-1.4.3 apscheduler-3.6.3 async-timeout-3.0.1 attrs-19.3.0 boto3-1.16.50 botocore-1.19.50 colorclass-2.2.0 coloredlogs-14.3 colorhash-1.0.3 contextvars-2.4 cryptography-2.9.2 dnspython-1.16.0 fbmessenger-6.0.0 gitdb-4.0.5 h11-0.9.0 httpcore-0.11.1 httptools-0.1.1 httpx-0.15.4 humanfriendly-9.1 idna-ssl-1.1.0 immutables-0.14 isodate-0.6.0 jmespath-0.10.0 joblib-0.15.1 jsonpickle-1.4.2 jsonschema-3.2.0 kafka-python-1.4.7 mattermostwrapper-2.2 multidict-5.1.0 pamqp-2.3.0 pika-1.1.0 prompt-toolkit-3.0.9 psycopg2-binary-2.8.6 pyTelegramBotAPI-3.7.4 pydot-1.4.1 pykwalify-1.7.0 pymongo-3.10.1 python-crfsuite-0.9.7 python-editor-1.0.4 python-engineio-3.13.2 python-socketio-4.6.1 pytz-2020.5 questionary-1.5.2 rasa-2.2.3 rasa-sdk-2.2.0 rasa-x-0.34.0 redis-3.5.3 regex-2020.9.27 requests-toolbelt-0.9.1 rfc3986-1.4.0 rocketchat-API-1.9.1 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 s3transfer-0.3.3 sanic-20.12.1 sanic-cors-0.10.0.post3 sanic-jwt-1.4.1 sanic-plugins-framework-0.9.4.post1 sentry-sdk-0.19.5 sklearn-crfsuite-0.3.6 slackclient-2.9.3 smmap-3.0.4 sniffio-1.2.0 tensorflow-2.3.2 tensorflow-addons-0.12.0 tensorflow-estimator-2.3.0 tensorflow-hub-0.9.0 tensorflow-text-2.3.0 terminaltables-3.1.0 twilio-6.45.4 ujson-1.35 uvloop-0.14.0 webexteamssdk-1.6 websockets-8.1 yarl-1.6.3

# %%
# !pip install rasa[spacy]
# !python -m spacy download en_core_web_md
# !python -m spacy link en_core_web_md en
# Out:
# Requirement already satisfied: rasa[spacy] in /usr/local/lib/python3.6/dist-packages (2.2.3)
# Requirement already satisfied: sklearn-crfsuite<0.4,>=0.3 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (0.3.6)
# Requirement already satisfied: pytz<2021.0,>=2019.1 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2020.5)
# Requirement already satisfied: redis<4.0,>=3.4 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (3.5.3)
# Requirement already satisfied: sanic<21.0.0,>=19.12.2 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (20.12.1)
# Requirement already satisfied: webexteamssdk<1.7.0,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.6)
# Requirement already satisfied: tensorflow-probability<0.12,>=0.11 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (0.11.0)
# Requirement already satisfied: jsonschema<3.3,>=3.2 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (3.2.0)
# Collecting prompt-toolkit<3.0,>=2.0
#   Downloading https://files.pythonhosted.org/packages/87/61/2dfea88583d5454e3a64f9308a686071d58d59a55db638268a6413e1eb6d/prompt_toolkit-2.0.10-py3-none-any.whl (340kB)
#      |████████████████████████████████| 348kB 17.8MB/s
# Requirement already satisfied: coloredlogs<15,>=10 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (14.3)
# Requirement already satisfied: tensorflow-addons<=0.12,>=0.10 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (0.12.0)
# Requirement already satisfied: attrs<20.3,>=19.3 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (19.3.0)
# Requirement already satisfied: scikit-learn<0.24,>=0.22 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (0.22.2.post1)
# Requirement already satisfied: tqdm<4.51,>=4.31 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (4.41.1)
# Requirement already satisfied: cloudpickle<1.5,>=1.2 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.3.0)
# Requirement already satisfied: numpy<2.0,>=1.16 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.19.4)
# Requirement already satisfied: pyTelegramBotAPI<4.0.0,>=3.7.3 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (3.7.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (51.0.0)
# Requirement already satisfied: slackclient<3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.9.3)
# Requirement already satisfied: networkx<2.6,>=2.4 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.5)
# Requirement already satisfied: mattermostwrapper<2.3,>=2.2 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.2)
# Requirement already satisfied: colorhash<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.0.3)
# Requirement already satisfied: packaging<21.0,>=20.0 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (20.8)
# Requirement already satisfied: pykwalify<1.8.0,>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.7.0)
# Requirement already satisfied: rocketchat_API<1.10.0,>=0.6.31 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.9.1)
# Requirement already satisfied: sentry-sdk<0.20.0,>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (0.19.5)
# Requirement already satisfied: SQLAlchemy<1.4.0,>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.3.20)
# Collecting aiohttp<3.7,>=3.6
#   Downloading https://files.pythonhosted.org/packages/78/a6/93acfa8f8b3573c4445ace2f266de62783231923706a4c3ab705e7d43497/aiohttp-3.6.3-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 47.0MB/s
# Requirement already satisfied: twilio<6.46,>=6.26 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (6.45.4)
# Requirement already satisfied: psycopg2-binary<2.9.0,>=2.8.2 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.8.6)
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.8.1)
# Requirement already satisfied: tensorflow-estimator<2.4,>=2.3 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.3.0)
# Requirement already satisfied: tensorflow_hub<0.10,>=0.9 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (0.9.0)
# Requirement already satisfied: tensorflow-text<2.4,>=2.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.3.0)
# Requirement already satisfied: ruamel.yaml<0.17.0,>=0.16.5 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (0.16.12)
# Requirement already satisfied: fbmessenger<6.1.0,>=6.0.0 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (6.0.0)
# Requirement already satisfied: aio-pika<7.0.0,>=6.7.1 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (6.7.1)
# Requirement already satisfied: matplotlib<3.4,>=3.1 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (3.2.2)
# Requirement already satisfied: sanic-jwt<1.5.0,>=1.3.2 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.4.1)
# Requirement already satisfied: ujson<4.0,>=1.35 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.35)
# Requirement already satisfied: kafka-python<3.0,>=1.4 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.4.7)
# Requirement already satisfied: boto3<2.0,>=1.12 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.16.50)
# Requirement already satisfied: jsonpickle<1.5,>=1.3 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.4.2)
# Requirement already satisfied: questionary<1.6.0,>=1.5.1 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.5.2)
# Requirement already satisfied: terminaltables<3.2.0,>=3.1.0 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (3.1.0)
# Requirement already satisfied: requests<3.0,>=2.23 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.23.0)
# Requirement already satisfied: tensorflow<2.4,>=2.3 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.3.2)
# Requirement already satisfied: pymongo[srv,tls]<3.11,>=3.8 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (3.10.1)
# Requirement already satisfied: python-engineio<3.14,>=3.11 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (3.13.2)
# Requirement already satisfied: regex<2020.10,>=2020.6 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2020.9.27)
# Requirement already satisfied: scipy<2.0.0,>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.4.1)
# Requirement already satisfied: absl-py<0.11,>=0.9 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (0.10.0)
# Collecting multidict<5.0,>=4.6
#   Downloading https://files.pythonhosted.org/packages/1a/95/f50352b5366e7d579e8b99631680a9e32e1b22adfa1629a8f23b1d22d5e2/multidict-4.7.6-cp36-cp36m-manylinux1_x86_64.whl (148kB)
#      |████████████████████████████████| 153kB 47.3MB/s
# Requirement already satisfied: oauth2client==4.1.3 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (4.1.3)
# Requirement already satisfied: async_generator<1.11,>=1.10 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.10)
# Requirement already satisfied: rasa-sdk<3.0.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.2.0)
# Requirement already satisfied: colorclass<2.3,>=2.2 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.2.0)
# Requirement already satisfied: sanic-cors<0.11.0,>=0.10.0b1 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (0.10.0.post3)
# Requirement already satisfied: python-socketio<4.7,>=4.4 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (4.6.1)
# Requirement already satisfied: apscheduler<3.7,>=3.6 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (3.6.3)
# Requirement already satisfied: PyJWT<1.8,>=1.7 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.7.1)
# Requirement already satisfied: pydot<1.5,>=1.4 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (1.4.1)
# Requirement already satisfied: joblib<0.16.0,>=0.15.1 in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (0.15.1)
# Requirement already satisfied: spacy<2.3,>=2.1; extra == "spacy" or extra == "full" in /usr/local/lib/python3.6/dist-packages (from rasa[spacy]) (2.2.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite<0.4,>=0.3->rasa[spacy]) (1.15.0)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite<0.4,>=0.3->rasa[spacy]) (0.9.7)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite<0.4,>=0.3->rasa[spacy]) (0.8.7)
# Requirement already satisfied: websockets<9.0,>=8.1 in /usr/local/lib/python3.6/dist-packages (from sanic<21.0.0,>=19.12.2->rasa[spacy]) (8.1)
# Requirement already satisfied: httptools>=0.0.10 in /usr/local/lib/python3.6/dist-packages (from sanic<21.0.0,>=19.12.2->rasa[spacy]) (0.1.1)
# Requirement already satisfied: uvloop>=0.5.3; sys_platform != "win32" and implementation_name == "cpython" in /usr/local/lib/python3.6/dist-packages (from sanic<21.0.0,>=19.12.2->rasa[spacy]) (0.14.0)
# Requirement already satisfied: httpx==0.15.4 in /usr/local/lib/python3.6/dist-packages (from sanic<21.0.0,>=19.12.2->rasa[spacy]) (0.15.4)
# Requirement already satisfied: aiofiles>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from sanic<21.0.0,>=19.12.2->rasa[spacy]) (0.6.0)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.6/dist-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa[spacy]) (0.9.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa[spacy]) (0.16.0)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability<0.12,>=0.11->rasa[spacy]) (0.3.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability<0.12,>=0.11->rasa[spacy]) (4.4.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.6/dist-packages (from tensorflow-probability<0.12,>=0.11->rasa[spacy]) (0.1.5)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from jsonschema<3.3,>=3.2->rasa[spacy]) (3.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema<3.3,>=3.2->rasa[spacy]) (0.17.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<3.0,>=2.0->rasa[spacy]) (0.2.5)
# Requirement already satisfied: humanfriendly>=7.1 in /usr/local/lib/python3.6/dist-packages (from coloredlogs<15,>=10->rasa[spacy]) (9.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons<=0.12,>=0.10->rasa[spacy]) (2.7.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging<21.0,>=20.0->rasa[spacy]) (2.4.7)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.6/dist-packages (from pykwalify<1.8.0,>=1.7.0->rasa[spacy]) (3.13)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.6/dist-packages (from pykwalify<1.8.0,>=1.7.0->rasa[spacy]) (0.6.2)
# Requirement already satisfied: urllib3>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from sentry-sdk<0.20.0,>=0.17.0->rasa[spacy]) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from sentry-sdk<0.20.0,>=0.17.0->rasa[spacy]) (2020.12.5)
# Requirement already satisfied: idna-ssl>=1.0; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp<3.7,>=3.6->rasa[spacy]) (1.1.0)
# Collecting yarl<1.6.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/a0/b4/2cbeaf2c3ea53865d9613b315fe24e78c66acedb1df7e4be4e064c87203b/yarl-1.5.1-cp36-cp36m-manylinux1_x86_64.whl (257kB)
#      |████████████████████████████████| 266kB 50.9MB/s
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp<3.7,>=3.6->rasa[spacy]) (3.7.4.3)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp<3.7,>=3.6->rasa[spacy]) (3.0.1)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp<3.7,>=3.6->rasa[spacy]) (3.0.4)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_hub<0.10,>=0.9->rasa[spacy]) (3.12.4)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from ruamel.yaml<0.17.0,>=0.16.5->rasa[spacy]) (0.2.2)
# Requirement already satisfied: aiormq<4,>=3.2.3 in /usr/local/lib/python3.6/dist-packages (from aio-pika<7.0.0,>=6.7.1->rasa[spacy]) (3.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib<3.4,>=3.1->rasa[spacy]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib<3.4,>=3.1->rasa[spacy]) (0.10.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3<2.0,>=1.12->rasa[spacy]) (0.10.0)
# Requirement already satisfied: botocore<1.20.0,>=1.19.50 in /usr/local/lib/python3.6/dist-packages (from boto3<2.0,>=1.12->rasa[spacy]) (1.19.50)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3<2.0,>=1.12->rasa[spacy]) (0.3.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.23->rasa[spacy]) (2.10)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa[spacy]) (1.12.1)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa[spacy]) (2.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa[spacy]) (3.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa[spacy]) (0.36.2)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa[spacy]) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa[spacy]) (0.2.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa[spacy]) (1.1.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa[spacy]) (1.32.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa[spacy]) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.4,>=2.3->rasa[spacy]) (1.1.0)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0; extra == "srv" in /usr/local/lib/python3.6/dist-packages (from pymongo[srv,tls]<3.11,>=3.8->rasa[spacy]) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client==4.1.3->rasa[spacy]) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client==4.1.3->rasa[spacy]) (4.6)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client==4.1.3->rasa[spacy]) (0.17.4)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client==4.1.3->rasa[spacy]) (0.4.8)
# Requirement already satisfied: sanic-plugins-framework>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from sanic-cors<0.11.0,>=0.10.0b1->rasa[spacy]) (0.9.4.post1)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.6/dist-packages (from apscheduler<3.7,>=3.6->rasa[spacy]) (1.5.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.3,>=2.1; extra == "spacy" or extra == "full"->rasa[spacy]) (3.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.3,>=2.1; extra == "spacy" or extra == "full"->rasa[spacy]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.3,>=2.1; extra == "spacy" or extra == "full"->rasa[spacy]) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.3,>=2.1; extra == "spacy" or extra == "full"->rasa[spacy]) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.3,>=2.1; extra == "spacy" or extra == "full"->rasa[spacy]) (2.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.3,>=2.1; extra == "spacy" or extra == "full"->rasa[spacy]) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.3,>=2.1; extra == "spacy" or extra == "full"->rasa[spacy]) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.3,>=2.1; extra == "spacy" or extra == "full"->rasa[spacy]) (0.8.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.3,>=2.1; extra == "spacy" or extra == "full"->rasa[spacy]) (7.4.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.6/dist-packages (from httpx==0.15.4->sanic<21.0.0,>=19.12.2->rasa[spacy]) (1.4.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.6/dist-packages (from httpx==0.15.4->sanic<21.0.0,>=19.12.2->rasa[spacy]) (1.2.0)
# Requirement already satisfied: httpcore==0.11.* in /usr/local/lib/python3.6/dist-packages (from httpx==0.15.4->sanic<21.0.0,>=19.12.2->rasa[spacy]) (0.11.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->jsonschema<3.3,>=3.2->rasa[spacy]) (3.4.0)
# Requirement already satisfied: pamqp==2.3.0 in /usr/local/lib/python3.6/dist-packages (from aiormq<4,>=3.2.3->aio-pika<7.0.0,>=6.7.1->rasa[spacy]) (2.3.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa[spacy]) (0.4.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa[spacy]) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa[spacy]) (1.17.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa[spacy]) (3.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa[spacy]) (1.7.0)
# Requirement already satisfied: contextvars>=2.1; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from sniffio->httpx==0.15.4->sanic<21.0.0,>=19.12.2->rasa[spacy]) (2.4)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.6/dist-packages (from httpcore==0.11.*->httpx==0.15.4->sanic<21.0.0,>=19.12.2->rasa[spacy]) (0.9.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa[spacy]) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa[spacy]) (4.2.0)
# Requirement already satisfied: immutables>=0.9 in /usr/local/lib/python3.6/dist-packages (from contextvars>=2.1; python_version < "3.7"->sniffio->httpx==0.15.4->sanic<21.0.0,>=19.12.2->rasa[spacy]) (0.14)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow<2.4,>=2.3->rasa[spacy]) (3.1.0)
# ERROR: sanic 20.12.1 has requirement multidict<6.0,>=5.0, but you'll have multidict 4.7.6 which is incompatible.
# ERROR: jupyter-console 5.2.0 has requirement prompt-toolkit<2.0.0,>=1.0.0, but you'll have prompt-toolkit 2.0.10 which is incompatible.
# ERROR: ipython 5.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.4, but you'll have prompt-toolkit 2.0.10 which is incompatible.
# Installing collected packages: prompt-toolkit, multidict, yarl, aiohttp
#   Found existing installation: prompt-toolkit 3.0.9
#     Uninstalling prompt-toolkit-3.0.9:
#       Successfully uninstalled prompt-toolkit-3.0.9
#   Found existing installation: multidict 5.1.0
#     Uninstalling multidict-5.1.0:
#       Successfully uninstalled multidict-5.1.0
#   Found existing installation: yarl 1.6.3
#     Uninstalling yarl-1.6.3:
#       Successfully uninstalled yarl-1.6.3
#   Found existing installation: aiohttp 3.7.3
#     Uninstalling aiohttp-3.7.3:
#       Successfully uninstalled aiohttp-3.7.3
# Successfully installed aiohttp-3.6.3 multidict-4.7.6 prompt-toolkit-2.0.10 yarl-1.5.1
# Collecting en_core_web_md==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.2.5/en_core_web_md-2.2.5.tar.gz (96.4MB)
#      |████████████████████████████████| 96.4MB 1.2MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_md==2.2.5) (2.2.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (51.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (4.41.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (3.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (2.23.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (7.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (0.8.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.19.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (2.0.5)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (3.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (3.4.0)
# Building wheels for collected packages: en-core-web-md
#   Building wheel for en-core-web-md (setup.py) ... done
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.2.5-cp36-none-any.whl size=98051304 sha256=4ea7f0bdf84d1580065a51cc793c35be19d7e5411e41b53751918ab6f173bf8d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kvqh7wh8/wheels/df/94/ad/f5cf59224cea6b5686ac4fd1ad19c8a07bc026e13c36502d81
# Successfully built en-core-web-md
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')
#
# ✘ Link 'en' already exists
# To overwrite an existing link, use the --force flag

# %%
from rasa_nlu.converters import load_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-02f45d66ca55> in <module>()
# ----> 1 from rasa_nlu.converters import load_data
#
# ModuleNotFoundError: No module named 'rasa_nlu'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
