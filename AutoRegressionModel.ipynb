# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('airline-passenger-traffic.csv')

# %%
data['Passengers'].plot(figsize=(12,4))
plt.legend(loc='best')
plt.title('Airline Passen')
